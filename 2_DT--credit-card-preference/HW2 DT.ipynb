# %%
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import sys
import copy

# %%
# 1  import data 
# convert string to float
X_and_Y_train = np.loadtxt('data/pa2train.txt', delimiter=' ', usecols=range(23))
print "X_and_Y_train", X_and_Y_train.shape

X_and_Y_val = np.loadtxt('data/pa2validation.txt', delimiter=' ', usecols=range(23))
print "X_and_Y_val", X_and_Y_val.shape

X_and_Y_test = np.loadtxt('data/pa2test.txt', delimiter=' ', usecols=range(23))
print "X_and_Y_test is", X_and_Y_test.shape
# Out:
# X_and_Y_train (2000, 23)
# X_and_Y_val (1000, 23)
# X_and_Y_test is (1000, 23)

# %%
# passed in subset has 23 col, 22 features and  1 label
def calc_Entropy(feature,threshold,subset):

    counter1 = 0.0
    counter2 = 0.0
    counter3 = 0.0
    counter4 = 0.0
    trueNum = 0.0
    falseNum = 0.0
    totalNum = float(subset.shape[0])
    
    for i in range(subset.shape[0]):
        if(subset[i,feature] < threshold):
            trueNum+=1
            if (subset[i,22]==1):
                counter1+=1
            else:
                counter2+=1
        else:
            falseNum+=1
            if (subset[i,22]==1):
                counter3+=1
            else:
                counter4+=1
                
    prob1 = counter1/trueNum
    prob2 = counter2/trueNum
    prob3 = counter3/falseNum
    prob4 = counter4/falseNum
    probTrue = trueNum/totalNum
    probFalse = falseNum/totalNum
    
    if ((prob1==0 or prob2==0) and (prob3==0 or prob4==0)):
        entropy = 0
    elif ((prob1==0 or prob2==0) and prob3!=0 and prob4!=0):
        entropy = probFalse*(-prob3*np.log(prob3)-prob4*np.log(prob4))
    elif ((prob3==0 or prob4==0) and prob1!=0 and prob2!=0):
        entropy = probTrue*(-prob1*np.log(prob1)-prob2*np.log(prob2))
    else:
        entropy = probTrue*(-prob1*np.log(prob1)-prob2*np.log(prob2)) + \
        probFalse*(-prob3*np.log(prob3)-prob4*np.log(prob4))
    return entropy

# %%
# 2) Implement the DT
# data structure 
class DT_Node:
    def __init__(self,subset):
        self.left = None
        self.right =  None
        self.subset = subset
        self.threshold = None
        self.feature = None
        self.label = None
        self.pure = False

# %%
def findIndex(feature, threshold, sorted_by_feature):
    for i in range(sorted_by_feature.shape[0]-1):
        if ((sorted_by_feature[i,feature]) < threshold and (sorted_by_feature[i+1,feature]) > threshold):
            return i

# %%
# func: split the subset in a node into two subsets,left child node for the spliting rule 
# to be True and right child for the spliting rule ot be False
# notice that passed in node contains a subset, which is a 2D array, data by (feature+label)
# return: nothing
def splitRule(node):
    
    sorted_subset = copy.deepcopy(node.subset)
    #sort the subset data by all feature, axis=0 sort by col
    sorted_subset.sort(axis=0)
    
    Best_threshold=0
    Best_feature=0
    Min_entropy=sys.maxint

#     print "checking"
    for feature in range(sorted_subset.shape[1]-1):   #last col label not counted
        for data in range(sorted_subset.shape[0]-1):  
            #for all separable threshold, find its entropy
            if(sorted_subset[data,feature] != sorted_subset[data+1,feature]):
                #set threshold
                threshold = (sorted_subset[data,feature]+sorted_subset[data+1,feature])/2
                #calc entropy
                entropy = calc_Entropy(feature,threshold,node.subset)
                #update 
                if(entropy < Min_entropy):
                    Best_feature = feature
                    Best_threshold = threshold
                    Min_entropy = entropy
#                     print "Best_threshold,",Best_threshold, \
#                     "Best_feature",Best_feature,"Min_entropy",Min_entropy
                
    #   sorted by feature 
    sorted_by_feature = node.subset[np.argsort(node.subset[:,Best_feature])] 
    #   find spliting threshold index
    Best_threshold_index = findIndex(Best_feature, Best_threshold, sorted_by_feature)
    #   left child->True,  right child->false  of spliting rule
    left_subset = sorted_by_feature[:(Best_threshold_index+1),:] 
    right_subset = sorted_by_feature[(Best_threshold_index+1):,:]

    # set properties in the node
    node.threshold = Best_threshold
    node.feature = Best_feature
    node.left = DT_Node(left_subset)
    node.right = DT_Node(right_subset)

# %%
# func: check if the subset in a node is pure 
# return: Ture/False
def pureNode(node):
    label = node.subset[0,22]
    for i in range (node.subset.shape[0]):
        if(node.subset[i,22]!=label):
            return False
    return True

# %%
def ID3_helper(node):

    splitRule(node)
    
    if (pureNode(node.left)==True):  
        node.left.pure = True 
        node.left.label = node.left.subset[0,22]
    else:  
        #recursive call
        ID3_helper(node.left)
        
    if (pureNode(node.right)==True):
        node.right.pure = True 
        node.right.label = node.right.subset[0,22]
    else:  
        #recursive call
        ID3_helper(node.right)

# %%
def ID3_alg(X_and_Y_train):
    #inti   
    root = DT_Node(X_and_Y_train)
    #check if root can split 
    
    #call helper function to split the node recursively
    ID3_helper(root) 
    return root

# %%
# 3) call ID3 algorithm to build the tree

root = ID3_alg(X_and_Y_train)

# %%
# traverse the tree using bfs
def bfs(root):
    queue = []
    queue.append(root)
    while queue:
        currNode = queue.pop(0)
        if(currNode.pure == False):
            print "--------------------\n Internal node: ",repr(currNode),"\nleft child: ",repr(currNode.left),\
            "\nright child: ",repr(currNode.right),"\nsplit rule: feature",currNode.feature+1," < ",currNode.threshold,\
            "\nsubset size: ",currNode.subset.shape[0]
        else:
            print "--------------------\n Leaf Node: ",repr(currNode),"\n label: ",currNode.label,\
            "\subset size: ",currNode.subset.shape[0]
        if(currNode.left!=None):
            queue.append(currNode.left) 
        if(currNode.right!=None):
            queue.append(currNode.right)

# %% [markdown]
# # Part1 graphing the tree

# %%
# 4) call bfs to print the tree
bfs(root)
# Out:
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7f0e0>
# left child:  <__main__.DT_Node instance at 0x118c7f320>
# right child:  <__main__.DT_Node instance at 0x118dd4638>
# split rule: feature 5  <  0.5
# subset size:  2000
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7f320>
# left child:  <__main__.DT_Node instance at 0x118dd45f0>
# right child:  <__main__.DT_Node instance at 0x118dd4680>
# split rule: feature 1  <  415000.0
# subset size:  1319
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd4638>
# left child:  <__main__.DT_Node instance at 0x118d9eab8>
# right child:  <__main__.DT_Node instance at 0x118d9eb00>
# split rule: feature 5  <  1.5
# subset size:  681
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd45f0>
# left child:  <__main__.DT_Node instance at 0x118dd46c8>
# right child:  <__main__.DT_Node instance at 0x118dd4710>
# split rule: feature 17  <  2506.5
# subset size:  1284
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd4680>
# left child:  <__main__.DT_Node instance at 0x118d9e758>
# right child:  <__main__.DT_Node instance at 0x118d9e7a0>
# split rule: feature 21  <  208.0
# subset size:  35
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d9eab8>
# left child:  <__main__.DT_Node instance at 0x118d9eb48>
# right child:  <__main__.DT_Node instance at 0x118d9eb90>
# split rule: feature 20  <  584.5
# subset size:  292
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d9eb00>
# left child:  <__main__.DT_Node instance at 0x118da2e18>
# right child:  <__main__.DT_Node instance at 0x118da2e60>
# split rule: feature 21  <  2006.0
# subset size:  389
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd46c8>
# left child:  <__main__.DT_Node instance at 0x118dd4758>
# right child:  <__main__.DT_Node instance at 0x118dd47a0>
# split rule: feature 1  <  75000.0
# subset size:  704
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd4710>
# left child:  <__main__.DT_Node instance at 0x118da4ea8>
# right child:  <__main__.DT_Node instance at 0x118da4ef0>
# split rule: feature 1  <  25000.0
# subset size:  580
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9e758>
#  label:  1.0 \subset size:  4
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d9e7a0>
# left child:  <__main__.DT_Node instance at 0x118d9e7e8>
# right child:  <__main__.DT_Node instance at 0x118d9e830>
# split rule: feature 17  <  2174.0
# subset size:  31
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d9eb48>
# left child:  <__main__.DT_Node instance at 0x118d9ebd8>
# right child:  <__main__.DT_Node instance at 0x118d9ec20>
# split rule: feature 12  <  231.5
# subset size:  134
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d9eb90>
# left child:  <__main__.DT_Node instance at 0x118da27e8>
# right child:  <__main__.DT_Node instance at 0x118da2830>
# split rule: feature 12  <  1461.0
# subset size:  158
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da2e18>
# left child:  <__main__.DT_Node instance at 0x118da2ea8>
# right child:  <__main__.DT_Node instance at 0x118da2ef0>
# split rule: feature 19  <  2476.0
# subset size:  232
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da2e60>
# left child:  <__main__.DT_Node instance at 0x1190f97e8>
# right child:  <__main__.DT_Node instance at 0x1190f9830>
# split rule: feature 19  <  13075.0
# subset size:  157
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd4758>
# left child:  <__main__.DT_Node instance at 0x118dd47e8>
# right child:  <__main__.DT_Node instance at 0x118dd4830>
# split rule: feature 13  <  46620.5
# subset size:  393
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd47a0>
# left child:  <__main__.DT_Node instance at 0x118c7b248>
# right child:  <__main__.DT_Node instance at 0x118c7b290>
# split rule: feature 1  <  115000.0
# subset size:  311
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da4ea8>
# left child:  <__main__.DT_Node instance at 0x118da4f38>
# right child:  <__main__.DT_Node instance at 0x118da4f80>
# split rule: feature 19  <  750.0
# subset size:  9
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da4ef0>
# left child:  <__main__.DT_Node instance at 0x118da4fc8>
# right child:  <__main__.DT_Node instance at 0x118d95050>
# split rule: feature 18  <  14935.5
# subset size:  571
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9e7e8>
#  label:  0.0 \subset size:  9
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d9e830>
# left child:  <__main__.DT_Node instance at 0x118d9e878>
# right child:  <__main__.DT_Node instance at 0x118d9e8c0>
# split rule: feature 22  <  2121.5
# subset size:  22
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d9ebd8>
# left child:  <__main__.DT_Node instance at 0x118d9ec68>
# right child:  <__main__.DT_Node instance at 0x118d9ecb0>
# split rule: feature 4  <  2.5
# subset size:  54
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d9ec20>
# left child:  <__main__.DT_Node instance at 0x118da2098>
# right child:  <__main__.DT_Node instance at 0x118da20e0>
# split rule: feature 12  <  316.0
# subset size:  80
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da27e8>
# left child:  <__main__.DT_Node instance at 0x118da2878>
# right child:  <__main__.DT_Node instance at 0x118da28c0>
# split rule: feature 2  <  1.5
# subset size:  22
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da2830>
# left child:  <__main__.DT_Node instance at 0x118da2ab8>
# right child:  <__main__.DT_Node instance at 0x118da2b00>
# split rule: feature 21  <  1911.5
# subset size:  136
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da2ea8>
# left child:  <__main__.DT_Node instance at 0x118da2f38>
# right child:  <__main__.DT_Node instance at 0x118da2f80>
# split rule: feature 19  <  2426.0
# subset size:  182
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da2ef0>
#  label:  1.0 \subset size:  50
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x1190f97e8>
#  label:  1.0 \subset size:  147
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x1190f9830>
# left child:  <__main__.DT_Node instance at 0x1190f9878>
# right child:  <__main__.DT_Node instance at 0x1190f98c0>
# split rule: feature 19  <  13894.0
# subset size:  10
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd47e8>
# left child:  <__main__.DT_Node instance at 0x118dd4878>
# right child:  <__main__.DT_Node instance at 0x118dd48c0>
# split rule: feature 1  <  25000.0
# subset size:  349
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd4830>
# left child:  <__main__.DT_Node instance at 0x118c99cf8>
# right child:  <__main__.DT_Node instance at 0x118c99d40>
# split rule: feature 2  <  1.5
# subset size:  44
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7b248>
# left child:  <__main__.DT_Node instance at 0x118c7b2d8>
# right child:  <__main__.DT_Node instance at 0x118c7b320>
# split rule: feature 11  <  668.5
# subset size:  35
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7b290>
# left child:  <__main__.DT_Node instance at 0x118c7b6c8>
# right child:  <__main__.DT_Node instance at 0x118c7b710>
# split rule: feature 1  <  125000.0
# subset size:  276
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da4f38>
#  label:  1.0 \subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da4f80>
#  label:  0.0 \subset size:  5
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da4fc8>
# left child:  <__main__.DT_Node instance at 0x118d95098>
# right child:  <__main__.DT_Node instance at 0x118d950e0>
# split rule: feature 12  <  204348.0
# subset size:  532
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d95050>
#  label:  0.0 \subset size:  39
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9e878>
#  label:  1.0 \subset size:  3
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d9e8c0>
# left child:  <__main__.DT_Node instance at 0x118d9e908>
# right child:  <__main__.DT_Node instance at 0x118d9e950>
# split rule: feature 1  <  475000.0
# subset size:  19
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d9ec68>
# left child:  <__main__.DT_Node instance at 0x118d9ecf8>
# right child:  <__main__.DT_Node instance at 0x118d9ed40>
# split rule: feature 1  <  190000.0
# subset size:  53
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9ecb0>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da2098>
#  label:  0.0 \subset size:  3
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da20e0>
# left child:  <__main__.DT_Node instance at 0x118da2128>
# right child:  <__main__.DT_Node instance at 0x118da2170>
# split rule: feature 18  <  6372.5
# subset size:  77
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da2878>
#  label:  1.0 \subset size:  10
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da28c0>
# left child:  <__main__.DT_Node instance at 0x118da2908>
# right child:  <__main__.DT_Node instance at 0x118da2950>
# split rule: feature 13  <  701.5
# subset size:  12
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da2ab8>
#  label:  1.0 \subset size:  84
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da2b00>
# left child:  <__main__.DT_Node instance at 0x118da2b48>
# right child:  <__main__.DT_Node instance at 0x118da2b90>
# split rule: feature 19  <  11929.0
# subset size:  52
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da2f38>
# left child:  <__main__.DT_Node instance at 0x118da2fc8>
# right child:  <__main__.DT_Node instance at 0x1190f9050>
# split rule: feature 7  <  1.0
# subset size:  181
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da2f80>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x1190f9878>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x1190f98c0>
#  label:  1.0 \subset size:  9
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd4878>
# left child:  <__main__.DT_Node instance at 0x118dd4908>
# right child:  <__main__.DT_Node instance at 0x118dd4950>
# split rule: feature 22  <  646.0
# subset size:  45
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd48c0>
# left child:  <__main__.DT_Node instance at 0x118dd4f38>
# right child:  <__main__.DT_Node instance at 0x118dd4f80>
# split rule: feature 12  <  16815.5
# subset size:  304
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c99cf8>
# left child:  <__main__.DT_Node instance at 0x118c99d88>
# right child:  <__main__.DT_Node instance at 0x118c99dd0>
# split rule: feature 11  <  58843.5
# subset size:  14
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c99d40>
# left child:  <__main__.DT_Node instance at 0x118c99f38>
# right child:  <__main__.DT_Node instance at 0x118c99f80>
# split rule: feature 11  <  50823.5
# subset size:  30
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7b2d8>
# left child:  <__main__.DT_Node instance at 0x118c7b368>
# right child:  <__main__.DT_Node instance at 0x118c7b3b0>
# split rule: feature 6  <  1.0
# subset size:  11
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7b320>
# left child:  <__main__.DT_Node instance at 0x118c7b488>
# right child:  <__main__.DT_Node instance at 0x118c7b4d0>
# split rule: feature 17  <  1340.0
# subset size:  24
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7b6c8>
#  label:  0.0 \subset size:  30
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7b710>
# left child:  <__main__.DT_Node instance at 0x118c7b758>
# right child:  <__main__.DT_Node instance at 0x118c7b7a0>
# split rule: feature 22  <  2888.5
# subset size:  246
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d95098>
# left child:  <__main__.DT_Node instance at 0x118d95128>
# right child:  <__main__.DT_Node instance at 0x118d95170>
# split rule: feature 11  <  146305.0
# subset size:  499
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d950e0>
#  label:  0.0 \subset size:  33
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d9e908>
# left child:  <__main__.DT_Node instance at 0x118d9e998>
# right child:  <__main__.DT_Node instance at 0x118d9e9e0>
# split rule: feature 19  <  14104.5
# subset size:  5
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d9e950>
# left child:  <__main__.DT_Node instance at 0x118d9ea28>
# right child:  <__main__.DT_Node instance at 0x118d9ea70>
# split rule: feature 19  <  63135.0
# subset size:  14
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9ecf8>
#  label:  1.0 \subset size:  25
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d9ed40>
# left child:  <__main__.DT_Node instance at 0x118d9ed88>
# right child:  <__main__.DT_Node instance at 0x118d9edd0>
# split rule: feature 3  <  0.5
# subset size:  28
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da2128>
# left child:  <__main__.DT_Node instance at 0x118da21b8>
# right child:  <__main__.DT_Node instance at 0x118da2200>
# split rule: feature 3  <  0.5
# subset size:  72
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da2170>
# left child:  <__main__.DT_Node instance at 0x118da2758>
# right child:  <__main__.DT_Node instance at 0x118da27a0>
# split rule: feature 1  <  225000.0
# subset size:  5
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da2908>
# left child:  <__main__.DT_Node instance at 0x118da2998>
# right child:  <__main__.DT_Node instance at 0x118da29e0>
# split rule: feature 15  <  903.5
# subset size:  9
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da2950>
#  label:  0.0 \subset size:  3
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da2b48>
# left child:  <__main__.DT_Node instance at 0x118da2bd8>
# right child:  <__main__.DT_Node instance at 0x118da2c20>
# split rule: feature 4  <  1.5
# subset size:  51
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da2b90>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da2fc8>
#  label:  1.0 \subset size:  66
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x1190f9050>
# left child:  <__main__.DT_Node instance at 0x1190f9098>
# right child:  <__main__.DT_Node instance at 0x1190f90e0>
# split rule: feature 1  <  65000.0
# subset size:  115
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd4908>
# left child:  <__main__.DT_Node instance at 0x118dd4998>
# right child:  <__main__.DT_Node instance at 0x118dd49e0>
# split rule: feature 18  <  1348.5
# subset size:  33
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd4950>
# left child:  <__main__.DT_Node instance at 0x118dd4cf8>
# right child:  <__main__.DT_Node instance at 0x118dd4d40>
# split rule: feature 17  <  1583.5
# subset size:  12
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd4f38>
# left child:  <__main__.DT_Node instance at 0x118dd4fc8>
# right child:  <__main__.DT_Node instance at 0x118c99050>
# split rule: feature 22  <  1514.0
# subset size:  137
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd4f80>
# left child:  <__main__.DT_Node instance at 0x118c99998>
# right child:  <__main__.DT_Node instance at 0x118c999e0>
# split rule: feature 4  <  2.5
# subset size:  167
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c99d88>
# left child:  <__main__.DT_Node instance at 0x118c99e18>
# right child:  <__main__.DT_Node instance at 0x118c99e60>
# split rule: feature 13  <  49649.5
# subset size:  10
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c99dd0>
#  label:  0.0 \subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c99f38>
#  label:  0.0 \subset size:  12
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c99f80>
# left child:  <__main__.DT_Node instance at 0x118c99fc8>
# right child:  <__main__.DT_Node instance at 0x118c7b050>
# split rule: feature 4  <  1.5
# subset size:  18
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7b368>
#  label:  1.0 \subset size:  7
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7b3b0>
# left child:  <__main__.DT_Node instance at 0x118c7b3f8>
# right child:  <__main__.DT_Node instance at 0x118c7b440>
# split rule: feature 1  <  85000.0
# subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7b488>
#  label:  0.0 \subset size:  10
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7b4d0>
# left child:  <__main__.DT_Node instance at 0x118c7b518>
# right child:  <__main__.DT_Node instance at 0x118c7b560>
# split rule: feature 17  <  1919.0
# subset size:  14
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7b758>
# left child:  <__main__.DT_Node instance at 0x118c7b7e8>
# right child:  <__main__.DT_Node instance at 0x118c7b830>
# split rule: feature 11  <  19215.0
# subset size:  195
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7b7a0>
# left child:  <__main__.DT_Node instance at 0x118da4878>
# right child:  <__main__.DT_Node instance at 0x118da48c0>
# split rule: feature 1  <  190000.0
# subset size:  51
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d95128>
# left child:  <__main__.DT_Node instance at 0x118d951b8>
# right child:  <__main__.DT_Node instance at 0x118d95200>
# split rule: feature 18  <  10835.5
# subset size:  454
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d95170>
# left child:  <__main__.DT_Node instance at 0x118d9e3f8>
# right child:  <__main__.DT_Node instance at 0x118d9e440>
# split rule: feature 19  <  4502.5
# subset size:  45
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9e998>
#  label:  1.0 \subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9e9e0>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9ea28>
#  label:  0.0 \subset size:  12
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9ea70>
#  label:  1.0 \subset size:  2
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d9ed88>
# left child:  <__main__.DT_Node instance at 0x118d9ee18>
# right child:  <__main__.DT_Node instance at 0x118d9ee60>
# split rule: feature 1  <  255000.0
# subset size:  3
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d9edd0>
# left child:  <__main__.DT_Node instance at 0x118d9ef38>
# right child:  <__main__.DT_Node instance at 0x118d9ef80>
# split rule: feature 22  <  839.5
# subset size:  25
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da21b8>
# left child:  <__main__.DT_Node instance at 0x118da2248>
# right child:  <__main__.DT_Node instance at 0x118da2290>
# split rule: feature 1  <  25000.0
# subset size:  19
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da2200>
# left child:  <__main__.DT_Node instance at 0x118da2488>
# right child:  <__main__.DT_Node instance at 0x118da24d0>
# split rule: feature 15  <  15900.0
# subset size:  53
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da2758>
#  label:  0.0 \subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da27a0>
#  label:  1.0 \subset size:  1
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da2998>
# left child:  <__main__.DT_Node instance at 0x118da2a28>
# right child:  <__main__.DT_Node instance at 0x118da2a70>
# split rule: feature 21  <  967.5
# subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da29e0>
#  label:  1.0 \subset size:  5
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da2bd8>
#  label:  1.0 \subset size:  24
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da2c20>
# left child:  <__main__.DT_Node instance at 0x118da2c68>
# right child:  <__main__.DT_Node instance at 0x118da2cb0>
# split rule: feature 17  <  8400.0
# subset size:  27
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x1190f9098>
# left child:  <__main__.DT_Node instance at 0x1190f9128>
# right child:  <__main__.DT_Node instance at 0x1190f9170>
# split rule: feature 19  <  1867.0
# subset size:  74
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x1190f90e0>
# left child:  <__main__.DT_Node instance at 0x1190f9368>
# right child:  <__main__.DT_Node instance at 0x1190f93b0>
# split rule: feature 4  <  1.5
# subset size:  41
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd4998>
# left child:  <__main__.DT_Node instance at 0x118dd4a28>
# right child:  <__main__.DT_Node instance at 0x118dd4a70>
# split rule: feature 12  <  7776.0
# subset size:  19
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dd49e0>
#  label:  0.0 \subset size:  14
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd4cf8>
# left child:  <__main__.DT_Node instance at 0x118dd4d88>
# right child:  <__main__.DT_Node instance at 0x118dd4dd0>
# split rule: feature 11  <  585.0
# subset size:  9
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dd4d40>
#  label:  1.0 \subset size:  3
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd4fc8>
# left child:  <__main__.DT_Node instance at 0x118c99098>
# right child:  <__main__.DT_Node instance at 0x118c990e0>
# split rule: feature 17  <  1641.0
# subset size:  107
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c99050>
#  label:  0.0 \subset size:  30
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c99998>
# left child:  <__main__.DT_Node instance at 0x118c99a28>
# right child:  <__main__.DT_Node instance at 0x118c99a70>
# split rule: feature 17  <  2503.0
# subset size:  166
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c999e0>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c99e18>
#  label:  1.0 \subset size:  6
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c99e60>
# left child:  <__main__.DT_Node instance at 0x118c99ea8>
# right child:  <__main__.DT_Node instance at 0x118c99ef0>
# split rule: feature 16  <  28057.0
# subset size:  4
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c99fc8>
# left child:  <__main__.DT_Node instance at 0x118c7b098>
# right child:  <__main__.DT_Node instance at 0x118c7b0e0>
# split rule: feature 11  <  59051.0
# subset size:  6
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7b050>
# left child:  <__main__.DT_Node instance at 0x118c7b1b8>
# right child:  <__main__.DT_Node instance at 0x118c7b200>
# split rule: feature 1  <  55000.0
# subset size:  12
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7b3f8>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7b440>
#  label:  0.0 \subset size:  3
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7b518>
# left child:  <__main__.DT_Node instance at 0x118c7b5a8>
# right child:  <__main__.DT_Node instance at 0x118c7b5f0>
# split rule: feature 13  <  23252.0
# subset size:  10
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7b560>
#  label:  0.0 \subset size:  4
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7b7e8>
# left child:  <__main__.DT_Node instance at 0x118c7b878>
# right child:  <__main__.DT_Node instance at 0x118c7b8c0>
# split rule: feature 1  <  185000.0
# subset size:  180
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7b830>
#  label:  0.0 \subset size:  15
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da4878>
# left child:  <__main__.DT_Node instance at 0x118da4908>
# right child:  <__main__.DT_Node instance at 0x118da4950>
# split rule: feature 20  <  7026.0
# subset size:  9
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da48c0>
# left child:  <__main__.DT_Node instance at 0x118da4a28>
# right child:  <__main__.DT_Node instance at 0x118da4a70>
# split rule: feature 11  <  49829.0
# subset size:  42
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d951b8>
# left child:  <__main__.DT_Node instance at 0x118d95248>
# right child:  <__main__.DT_Node instance at 0x118d95290>
# split rule: feature 21  <  809.5
# subset size:  443
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d95200>
# left child:  <__main__.DT_Node instance at 0x118d9e2d8>
# right child:  <__main__.DT_Node instance at 0x118d9e320>
# split rule: feature 13  <  14402.0
# subset size:  11
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d9e3f8>
# left child:  <__main__.DT_Node instance at 0x118d9e488>
# right child:  <__main__.DT_Node instance at 0x118d9e4d0>
# split rule: feature 15  <  95643.0
# subset size:  10
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d9e440>
# left child:  <__main__.DT_Node instance at 0x118d9e5a8>
# right child:  <__main__.DT_Node instance at 0x118d9e5f0>
# split rule: feature 19  <  9000.0
# subset size:  35
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9ee18>
#  label:  1.0 \subset size:  1
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d9ee60>
# left child:  <__main__.DT_Node instance at 0x118d9eea8>
# right child:  <__main__.DT_Node instance at 0x118d9eef0>
# split rule: feature 1  <  290000.0
# subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9ef38>
#  label:  1.0 \subset size:  22
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d9ef80>
# left child:  <__main__.DT_Node instance at 0x118d9efc8>
# right child:  <__main__.DT_Node instance at 0x118da2050>
# split rule: feature 1  <  220000.0
# subset size:  3
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da2248>
#  label:  1.0 \subset size:  6
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da2290>
# left child:  <__main__.DT_Node instance at 0x118da22d8>
# right child:  <__main__.DT_Node instance at 0x118da2320>
# split rule: feature 8  <  1.0
# subset size:  13
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da2488>
#  label:  1.0 \subset size:  32
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da24d0>
# left child:  <__main__.DT_Node instance at 0x118da2518>
# right child:  <__main__.DT_Node instance at 0x118da2560>
# split rule: feature 19  <  2555.5
# subset size:  21
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da2a28>
#  label:  0.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da2a70>
#  label:  1.0 \subset size:  2
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da2c68>
# left child:  <__main__.DT_Node instance at 0x118da2cf8>
# right child:  <__main__.DT_Node instance at 0x118da2d40>
# split rule: feature 15  <  29380.5
# subset size:  26
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da2cb0>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x1190f9128>
#  label:  1.0 \subset size:  64
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x1190f9170>
# left child:  <__main__.DT_Node instance at 0x1190f91b8>
# right child:  <__main__.DT_Node instance at 0x1190f9200>
# split rule: feature 2  <  1.5
# subset size:  10
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x1190f9368>
#  label:  1.0 \subset size:  17
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x1190f93b0>
# left child:  <__main__.DT_Node instance at 0x1190f93f8>
# right child:  <__main__.DT_Node instance at 0x1190f9440>
# split rule: feature 14  <  455.5
# subset size:  24
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dd4a28>
#  label:  0.0 \subset size:  7
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd4a70>
# left child:  <__main__.DT_Node instance at 0x118dd4ab8>
# right child:  <__main__.DT_Node instance at 0x118dd4b00>
# split rule: feature 22  <  97.5
# subset size:  12
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dd4d88>
#  label:  1.0 \subset size:  2
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd4dd0>
# left child:  <__main__.DT_Node instance at 0x118dd4e18>
# right child:  <__main__.DT_Node instance at 0x118dd4e60>
# split rule: feature 12  <  3124.0
# subset size:  7
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c99098>
# left child:  <__main__.DT_Node instance at 0x118c99128>
# right child:  <__main__.DT_Node instance at 0x118c99170>
# split rule: feature 11  <  46792.5
# subset size:  95
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c990e0>
# left child:  <__main__.DT_Node instance at 0x118c997e8>
# right child:  <__main__.DT_Node instance at 0x118c99830>
# split rule: feature 14  <  5583.0
# subset size:  12
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c99a28>
# left child:  <__main__.DT_Node instance at 0x118c99ab8>
# right child:  <__main__.DT_Node instance at 0x118c99b00>
# split rule: feature 14  <  25530.0
# subset size:  165
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c99a70>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c99ea8>
#  label:  0.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c99ef0>
#  label:  1.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7b098>
#  label:  1.0 \subset size:  3
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7b0e0>
# left child:  <__main__.DT_Node instance at 0x118c7b128>
# right child:  <__main__.DT_Node instance at 0x118c7b170>
# split rule: feature 11  <  59905.5
# subset size:  3
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7b1b8>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7b200>
#  label:  0.0 \subset size:  11
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7b5a8>
# left child:  <__main__.DT_Node instance at 0x118c7b638>
# right child:  <__main__.DT_Node instance at 0x118c7b680>
# split rule: feature 12  <  12973.0
# subset size:  6
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7b5f0>
#  label:  1.0 \subset size:  4
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7b878>
# left child:  <__main__.DT_Node instance at 0x118c7b908>
# right child:  <__main__.DT_Node instance at 0x118c7b950>
# split rule: feature 22  <  1189.0
# subset size:  52
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7b8c0>
# left child:  <__main__.DT_Node instance at 0x118c7bfc8>
# right child:  <__main__.DT_Node instance at 0x118da4050>
# split rule: feature 20  <  1728.0
# subset size:  128
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da4908>
# left child:  <__main__.DT_Node instance at 0x118da4998>
# right child:  <__main__.DT_Node instance at 0x118da49e0>
# split rule: feature 3  <  0.5
# subset size:  7
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da4950>
#  label:  0.0 \subset size:  2
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da4a28>
# left child:  <__main__.DT_Node instance at 0x118da4ab8>
# right child:  <__main__.DT_Node instance at 0x118da4b00>
# split rule: feature 22  <  10234.5
# subset size:  40
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da4a70>
#  label:  1.0 \subset size:  2
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d95248>
# left child:  <__main__.DT_Node instance at 0x118d952d8>
# right child:  <__main__.DT_Node instance at 0x118d95320>
# split rule: feature 17  <  3153.5
# subset size:  95
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d95290>
# left child:  <__main__.DT_Node instance at 0x118d95998>
# right child:  <__main__.DT_Node instance at 0x118d959e0>
# split rule: feature 11  <  1809.5
# subset size:  348
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9e2d8>
#  label:  0.0 \subset size:  6
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d9e320>
# left child:  <__main__.DT_Node instance at 0x118d9e368>
# right child:  <__main__.DT_Node instance at 0x118d9e3b0>
# split rule: feature 10  <  1.0
# subset size:  5
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d9e488>
# left child:  <__main__.DT_Node instance at 0x118d9e518>
# right child:  <__main__.DT_Node instance at 0x118d9e560>
# split rule: feature 4  <  1.5
# subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9e4d0>
#  label:  1.0 \subset size:  6
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d9e5a8>
# left child:  <__main__.DT_Node instance at 0x118d9e638>
# right child:  <__main__.DT_Node instance at 0x118d9e680>
# split rule: feature 16  <  194572.5
# subset size:  29
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d9e5f0>
# left child:  <__main__.DT_Node instance at 0x118d9e6c8>
# right child:  <__main__.DT_Node instance at 0x118d9e710>
# split rule: feature 9  <  1.0
# subset size:  6
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9eea8>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9eef0>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9efc8>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da2050>
#  label:  1.0 \subset size:  2
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da22d8>
# left child:  <__main__.DT_Node instance at 0x118da2368>
# right child:  <__main__.DT_Node instance at 0x118da23b0>
# split rule: feature 1  <  250000.0
# subset size:  9
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da2320>
#  label:  1.0 \subset size:  4
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da2518>
# left child:  <__main__.DT_Node instance at 0x118da25a8>
# right child:  <__main__.DT_Node instance at 0x118da25f0>
# split rule: feature 21  <  890.5
# subset size:  12
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da2560>
#  label:  1.0 \subset size:  9
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da2cf8>
# left child:  <__main__.DT_Node instance at 0x118da2d88>
# right child:  <__main__.DT_Node instance at 0x118da2dd0>
# split rule: feature 1  <  45000.0
# subset size:  10
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da2d40>
#  label:  1.0 \subset size:  16
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x1190f91b8>
#  label:  1.0 \subset size:  6
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x1190f9200>
# left child:  <__main__.DT_Node instance at 0x1190f9248>
# right child:  <__main__.DT_Node instance at 0x1190f9290>
# split rule: feature 1  <  40000.0
# subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x1190f93f8>
#  label:  0.0 \subset size:  2
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x1190f9440>
# left child:  <__main__.DT_Node instance at 0x1190f9488>
# right child:  <__main__.DT_Node instance at 0x1190f94d0>
# split rule: feature 1  <  335000.0
# subset size:  22
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd4ab8>
# left child:  <__main__.DT_Node instance at 0x118dd4b48>
# right child:  <__main__.DT_Node instance at 0x118dd4b90>
# split rule: feature 13  <  4860.0
# subset size:  7
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd4b00>
# left child:  <__main__.DT_Node instance at 0x118dd4c68>
# right child:  <__main__.DT_Node instance at 0x118dd4cb0>
# split rule: feature 11  <  7900.5
# subset size:  5
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dd4e18>
#  label:  0.0 \subset size:  4
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd4e60>
# left child:  <__main__.DT_Node instance at 0x118dd4ea8>
# right child:  <__main__.DT_Node instance at 0x118dd4ef0>
# split rule: feature 11  <  13850.5
# subset size:  3
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c99128>
# left child:  <__main__.DT_Node instance at 0x118c991b8>
# right child:  <__main__.DT_Node instance at 0x118c99200>
# split rule: feature 21  <  198.0
# subset size:  94
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c99170>
#  label:  1.0 \subset size:  1
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c997e8>
# left child:  <__main__.DT_Node instance at 0x118c99878>
# right child:  <__main__.DT_Node instance at 0x118c998c0>
# split rule: feature 15  <  1027.0
# subset size:  8
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c99830>
#  label:  1.0 \subset size:  4
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c99ab8>
# left child:  <__main__.DT_Node instance at 0x118c99b48>
# right child:  <__main__.DT_Node instance at 0x118c99b90>
# split rule: feature 16  <  21960.5
# subset size:  74
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c99b00>
#  label:  0.0 \subset size:  91
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7b128>
#  label:  0.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7b170>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7b638>
#  label:  1.0 \subset size:  3
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7b680>
#  label:  0.0 \subset size:  3
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7b908>
# left child:  <__main__.DT_Node instance at 0x118c7b998>
# right child:  <__main__.DT_Node instance at 0x118c7b9e0>
# split rule: feature 22  <  656.5
# subset size:  41
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7b950>
#  label:  0.0 \subset size:  11
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7bfc8>
# left child:  <__main__.DT_Node instance at 0x118da4098>
# right child:  <__main__.DT_Node instance at 0x118da40e0>
# split rule: feature 16  <  2474.5
# subset size:  106
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da4050>
#  label:  0.0 \subset size:  22
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da4998>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da49e0>
#  label:  1.0 \subset size:  6
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da4ab8>
# left child:  <__main__.DT_Node instance at 0x118da4b48>
# right child:  <__main__.DT_Node instance at 0x118da4b90>
# split rule: feature 12  <  4137.5
# subset size:  24
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da4b00>
# left child:  <__main__.DT_Node instance at 0x118da4c68>
# right child:  <__main__.DT_Node instance at 0x118da4cb0>
# split rule: feature 15  <  10768.0
# subset size:  16
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d952d8>
# left child:  <__main__.DT_Node instance at 0x118d95368>
# right child:  <__main__.DT_Node instance at 0x118d953b0>
# split rule: feature 10  <  1.0
# subset size:  18
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d95320>
# left child:  <__main__.DT_Node instance at 0x118d955a8>
# right child:  <__main__.DT_Node instance at 0x118d955f0>
# split rule: feature 19  <  35025.5
# subset size:  77
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d95998>
# left child:  <__main__.DT_Node instance at 0x118d95a28>
# right child:  <__main__.DT_Node instance at 0x118d95a70>
# split rule: feature 16  <  4690.5
# subset size:  22
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d959e0>
# left child:  <__main__.DT_Node instance at 0x118d95bd8>
# right child:  <__main__.DT_Node instance at 0x118d95c20>
# split rule: feature 21  <  4002.5
# subset size:  326
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9e368>
#  label:  1.0 \subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9e3b0>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9e518>
#  label:  0.0 \subset size:  3
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9e560>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9e638>
#  label:  0.0 \subset size:  28
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9e680>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9e6c8>
#  label:  1.0 \subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9e710>
#  label:  0.0 \subset size:  2
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da2368>
# left child:  <__main__.DT_Node instance at 0x118da23f8>
# right child:  <__main__.DT_Node instance at 0x118da2440>
# split rule: feature 13  <  36038.5
# subset size:  8
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da23b0>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da25a8>
#  label:  1.0 \subset size:  4
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da25f0>
# left child:  <__main__.DT_Node instance at 0x118da2638>
# right child:  <__main__.DT_Node instance at 0x118da2680>
# split rule: feature 21  <  2500.0
# subset size:  8
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da2d88>
#  label:  1.0 \subset size:  8
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da2dd0>
#  label:  0.0 \subset size:  2
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x1190f9248>
# left child:  <__main__.DT_Node instance at 0x1190f92d8>
# right child:  <__main__.DT_Node instance at 0x1190f9320>
# split rule: feature 11  <  19641.0
# subset size:  3
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x1190f9290>
#  label:  1.0 \subset size:  1
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x1190f9488>
# left child:  <__main__.DT_Node instance at 0x1190f9518>
# right child:  <__main__.DT_Node instance at 0x1190f9560>
# split rule: feature 8  <  4.5
# subset size:  21
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x1190f94d0>
#  label:  0.0 \subset size:  1
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd4b48>
# left child:  <__main__.DT_Node instance at 0x118dd4bd8>
# right child:  <__main__.DT_Node instance at 0x118dd4c20>
# split rule: feature 3  <  0.5
# subset size:  3
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dd4b90>
#  label:  1.0 \subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dd4c68>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dd4cb0>
#  label:  0.0 \subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dd4ea8>
#  label:  1.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dd4ef0>
#  label:  0.0 \subset size:  1
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c991b8>
# left child:  <__main__.DT_Node instance at 0x118c99248>
# right child:  <__main__.DT_Node instance at 0x118c99290>
# split rule: feature 6  <  1.0
# subset size:  46
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c99200>
# left child:  <__main__.DT_Node instance at 0x118c996c8>
# right child:  <__main__.DT_Node instance at 0x118c99710>
# split rule: feature 22  <  1206.5
# subset size:  48
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c99878>
# left child:  <__main__.DT_Node instance at 0x118c99908>
# right child:  <__main__.DT_Node instance at 0x118c99950>
# split rule: feature 13  <  825.5
# subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c998c0>
#  label:  0.0 \subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c99b48>
#  label:  0.0 \subset size:  51
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c99b90>
# left child:  <__main__.DT_Node instance at 0x118c99bd8>
# right child:  <__main__.DT_Node instance at 0x118c99c20>
# split rule: feature 15  <  21774.5
# subset size:  23
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7b998>
# left child:  <__main__.DT_Node instance at 0x118c7ba28>
# right child:  <__main__.DT_Node instance at 0x118c7ba70>
# split rule: feature 15  <  16077.5
# subset size:  33
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7b9e0>
# left child:  <__main__.DT_Node instance at 0x118c7bea8>
# right child:  <__main__.DT_Node instance at 0x118c7bef0>
# split rule: feature 1  <  155000.0
# subset size:  8
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da4098>
# left child:  <__main__.DT_Node instance at 0x118da4128>
# right child:  <__main__.DT_Node instance at 0x118da4170>
# split rule: feature 1  <  205000.0
# subset size:  95
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da40e0>
# left child:  <__main__.DT_Node instance at 0x118da4758>
# right child:  <__main__.DT_Node instance at 0x118da47a0>
# split rule: feature 11  <  10893.0
# subset size:  11
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da4b48>
#  label:  0.0 \subset size:  18
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da4b90>
# left child:  <__main__.DT_Node instance at 0x118da4bd8>
# right child:  <__main__.DT_Node instance at 0x118da4c20>
# split rule: feature 4  <  1.5
# subset size:  6
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da4c68>
# left child:  <__main__.DT_Node instance at 0x118da4cf8>
# right child:  <__main__.DT_Node instance at 0x118da4d40>
# split rule: feature 1  <  330000.0
# subset size:  9
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da4cb0>
# left child:  <__main__.DT_Node instance at 0x118da4e18>
# right child:  <__main__.DT_Node instance at 0x118da4e60>
# split rule: feature 14  <  98920.5
# subset size:  7
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d95368>
# ...
# split rule: feature 12  <  48957.0
# subset size:  6
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d95c68>
# left child:  <__main__.DT_Node instance at 0x118d95cf8>
# right child:  <__main__.DT_Node instance at 0x118d95d40>
# split rule: feature 16  <  38724.0
# subset size:  181
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d95cb0>
# left child:  <__main__.DT_Node instance at 0x118d9e098>
# right child:  <__main__.DT_Node instance at 0x118d9e0e0>
# split rule: feature 16  <  99997.0
# subset size:  33
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da26c8>
#  label:  0.0 \subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da2710>
#  label:  1.0 \subset size:  1
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x1190f95a8>
# left child:  <__main__.DT_Node instance at 0x1190f9638>
# right child:  <__main__.DT_Node instance at 0x1190f9680>
# split rule: feature 15  <  29979.5
# subset size:  11
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x1190f95f0>
#  label:  1.0 \subset size:  9
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c992d8>
#  label:  1.0 \subset size:  1
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c99320>
# left child:  <__main__.DT_Node instance at 0x118c99368>
# right child:  <__main__.DT_Node instance at 0x118c993b0>
# split rule: feature 22  <  1359.5
# subset size:  40
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c995a8>
#  label:  1.0 \subset size:  2
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c995f0>
# left child:  <__main__.DT_Node instance at 0x118c99638>
# right child:  <__main__.DT_Node instance at 0x118c99680>
# split rule: feature 11  <  1328.0
# subset size:  3
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c99758>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c997a0>
#  label:  0.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c99c68>
#  label:  0.0 \subset size:  20
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c99cb0>
#  label:  1.0 \subset size:  1
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7bab8>
# left child:  <__main__.DT_Node instance at 0x118c7bb48>
# right child:  <__main__.DT_Node instance at 0x118c7bb90>
# split rule: feature 1  <  150000.0
# subset size:  22
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7bb00>
#  label:  0.0 \subset size:  9
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7bf38>
#  label:  1.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7bf80>
#  label:  0.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da41b8>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da4200>
#  label:  0.0 \subset size:  40
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da4248>
# left child:  <__main__.DT_Node instance at 0x118da42d8>
# right child:  <__main__.DT_Node instance at 0x118da4320>
# split rule: feature 4  <  1.5
# subset size:  52
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da4290>
#  label:  1.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da47e8>
#  label:  1.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da4830>
#  label:  0.0 \subset size:  6
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da4d88>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da4dd0>
#  label:  1.0 \subset size:  6
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d95518>
#  label:  1.0 \subset size:  5
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d95560>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d956c8>
#  label:  0.0 \subset size:  45
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d95710>
# left child:  <__main__.DT_Node instance at 0x118d95758>
# right child:  <__main__.DT_Node instance at 0x118d957a0>
# split rule: feature 18  <  3745.0
# subset size:  28
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d95b48>
#  label:  0.0 \subset size:  5
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d95b90>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d95cf8>
#  label:  0.0 \subset size:  111
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d95d40>
# left child:  <__main__.DT_Node instance at 0x118d95d88>
# right child:  <__main__.DT_Node instance at 0x118d95dd0>
# split rule: feature 1  <  85000.0
# subset size:  70
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d9e098>
# left child:  <__main__.DT_Node instance at 0x118d9e128>
# right child:  <__main__.DT_Node instance at 0x118d9e170>
# split rule: feature 13  <  93450.5
# subset size:  23
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9e0e0>
#  label:  0.0 \subset size:  10
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x1190f9638>
# left child:  <__main__.DT_Node instance at 0x1190f96c8>
# right child:  <__main__.DT_Node instance at 0x1190f9710>
# split rule: feature 3  <  0.5
# subset size:  8
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x1190f9680>
# left child:  <__main__.DT_Node instance at 0x1190f9758>
# right child:  <__main__.DT_Node instance at 0x1190f97a0>
# split rule: feature 15  <  52494.0
# subset size:  3
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c99368>
# left child:  <__main__.DT_Node instance at 0x118c993f8>
# right child:  <__main__.DT_Node instance at 0x118c99440>
# split rule: feature 11  <  2973.0
# subset size:  39
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c993b0>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c99638>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c99680>
#  label:  0.0 \subset size:  2
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7bb48>
# left child:  <__main__.DT_Node instance at 0x118c7bbd8>
# right child:  <__main__.DT_Node instance at 0x118c7bc20>
# split rule: feature 1  <  135000.0
# subset size:  11
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7bb90>
# left child:  <__main__.DT_Node instance at 0x118c7bcf8>
# right child:  <__main__.DT_Node instance at 0x118c7bd40>
# split rule: feature 11  <  1240.0
# subset size:  11
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da42d8>
# left child:  <__main__.DT_Node instance at 0x118da4368>
# right child:  <__main__.DT_Node instance at 0x118da43b0>
# split rule: feature 11  <  237.5
# subset size:  26
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da4320>
# left child:  <__main__.DT_Node instance at 0x118da4488>
# right child:  <__main__.DT_Node instance at 0x118da44d0>
# split rule: feature 1  <  330000.0
# subset size:  26
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d95758>
# left child:  <__main__.DT_Node instance at 0x118d957e8>
# right child:  <__main__.DT_Node instance at 0x118d95830>
# split rule: feature 3  <  0.5
# subset size:  8
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d957a0>
#  label:  0.0 \subset size:  20
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d95d88>
# left child:  <__main__.DT_Node instance at 0x118d95e18>
# right child:  <__main__.DT_Node instance at 0x118d95e60>
# split rule: feature 18  <  500.0
# subset size:  26
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d95dd0>
#  label:  0.0 \subset size:  44
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d9e128>
# left child:  <__main__.DT_Node instance at 0x118d9e1b8>
# right child:  <__main__.DT_Node instance at 0x118d9e200>
# split rule: feature 11  <  4412.0
# subset size:  17
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d9e170>
# left child:  <__main__.DT_Node instance at 0x118d9e248>
# right child:  <__main__.DT_Node instance at 0x118d9e290>
# split rule: feature 14  <  104732.5
# subset size:  6
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x1190f96c8>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x1190f9710>
#  label:  1.0 \subset size:  7
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x1190f9758>
#  label:  0.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x1190f97a0>
#  label:  1.0 \subset size:  1
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c993f8>
# left child:  <__main__.DT_Node instance at 0x118c99488>
# right child:  <__main__.DT_Node instance at 0x118c994d0>
# split rule: feature 11  <  785.5
# subset size:  19
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c99440>
#  label:  0.0 \subset size:  20
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7bbd8>
# left child:  <__main__.DT_Node instance at 0x118c7bc68>
# right child:  <__main__.DT_Node instance at 0x118c7bcb0>
# split rule: feature 11  <  2790.0
# subset size:  3
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7bc20>
#  label:  0.0 \subset size:  8
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7bcf8>
# left child:  <__main__.DT_Node instance at 0x118c7bd88>
# right child:  <__main__.DT_Node instance at 0x118c7bdd0>
# split rule: feature 1  <  175000.0
# subset size:  9
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7bd40>
#  label:  1.0 \subset size:  2
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da4368>
# left child:  <__main__.DT_Node instance at 0x118da43f8>
# right child:  <__main__.DT_Node instance at 0x118da4440>
# split rule: feature 11  <  50.5
# subset size:  10
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da43b0>
#  label:  0.0 \subset size:  16
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da4488>
# left child:  <__main__.DT_Node instance at 0x118da4518>
# right child:  <__main__.DT_Node instance at 0x118da4560>
# split rule: feature 2  <  1.5
# subset size:  24
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da44d0>
#  label:  1.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d957e8>
#  label:  1.0 \subset size:  2
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d95830>
# left child:  <__main__.DT_Node instance at 0x118d95878>
# right child:  <__main__.DT_Node instance at 0x118d958c0>
# split rule: feature 11  <  94094.5
# subset size:  6
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d95e18>
#  label:  1.0 \subset size:  2
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d95e60>
# left child:  <__main__.DT_Node instance at 0x118d95ea8>
# right child:  <__main__.DT_Node instance at 0x118d95ef0>
# split rule: feature 1  <  75000.0
# subset size:  24
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9e1b8>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9e200>
#  label:  0.0 \subset size:  16
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9e248>
#  label:  1.0 \subset size:  5
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9e290>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c99488>
#  label:  0.0 \subset size:  13
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c994d0>
# left child:  <__main__.DT_Node instance at 0x118c99518>
# right child:  <__main__.DT_Node instance at 0x118c99560>
# split rule: feature 12  <  767.5
# subset size:  6
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7bc68>
#  label:  0.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7bcb0>
#  label:  1.0 \subset size:  1
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7bd88>
# left child:  <__main__.DT_Node instance at 0x118c7be18>
# right child:  <__main__.DT_Node instance at 0x118c7be60>
# split rule: feature 11  <  512.5
# subset size:  5
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7bdd0>
#  label:  0.0 \subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da43f8>
#  label:  0.0 \subset size:  9
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da4440>
#  label:  1.0 \subset size:  1
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da4518>
# left child:  <__main__.DT_Node instance at 0x118da45a8>
# right child:  <__main__.DT_Node instance at 0x118da45f0>
# split rule: feature 11  <  195.0
# subset size:  6
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da4560>
# left child:  <__main__.DT_Node instance at 0x118da4638>
# right child:  <__main__.DT_Node instance at 0x118da4680>
# split rule: feature 12  <  1246.5
# subset size:  18
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d95878>
#  label:  0.0 \subset size:  5
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d958c0>
#  label:  1.0 \subset size:  1
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d95ea8>
# left child:  <__main__.DT_Node instance at 0x118d95f38>
# right child:  <__main__.DT_Node instance at 0x118d95f80>
# split rule: feature 16  <  38969.0
# subset size:  21
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118d95ef0>
# left child:  <__main__.DT_Node instance at 0x118d95fc8>
# right child:  <__main__.DT_Node instance at 0x118d9e050>
# split rule: feature 2  <  1.5
# subset size:  3
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c99518>
#  label:  1.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c99560>
#  label:  0.0 \subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7be18>
#  label:  1.0 \subset size:  3
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7be60>
#  label:  0.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da45a8>
#  label:  1.0 \subset size:  3
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da45f0>
#  label:  0.0 \subset size:  3
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da4638>
#  label:  0.0 \subset size:  14
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118da4680>
# left child:  <__main__.DT_Node instance at 0x118da46c8>
# right child:  <__main__.DT_Node instance at 0x118da4710>
# split rule: feature 3  <  0.5
# subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d95f38>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d95f80>
#  label:  0.0 \subset size:  20
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d95fc8>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118d9e050>
#  label:  1.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da46c8>
#  label:  0.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118da4710>
#  label:  1.0 \subset size:  2

# %% [markdown]
# # Part2  training and test error

# %%
#purpose: func for predicting error given data
#return: error
def predict(data,root):

    wrong_counter = 0.0
    data_size = data.shape[0]
    
    for i in range(data_size):  
        currNode = root
        while(currNode.pure==False):
            if(data[i,currNode.feature] < currNode.threshold):
                currNode=currNode.left
            else:
                currNode=currNode.right
                
        if(currNode.label != data[i,22]):
            wrong_counter+=1

    error = wrong_counter/float(data_size)
    return error

# %%
training_error = predict(X_and_Y_train,root)
print "training_error: ",training_error

testing_error = predict(X_and_Y_test,root)
print "testing_error: ",testing_error

val_error = predict(X_and_Y_val,root)
print "validation_error: ",val_error
# Out:
# training_error:  0.0
# testing_error:  0.173
# validation_error:  0.179

# %% [markdown]
# # Part3  validation and test error after 1st and 2nd round pruning

# %%
def calcMajorityLabel(data):
    counts = np.bincount([int(i) for i in data[:,22]])
    return np.argmax(counts)

# %%
#purpose: for each node v in the tree, replace the tree starting at 
#root v by single node that predicts the majority label in v to get 
#tree T', if error(T')<=error(T), replace T by T'
def pruning(data,root,currNode,prev_error):
  
    #calculate majority
    majority_label = calcMajorityLabel(data)
      
    #replace the node by changing property inside the node
    currNode.label = majority_label
    currNode.pure = True
    
    after_error = predict(data,root)
    
    #change back since no progress made
    if(after_error > prev_error):
        currNode.label = None
        currNode.pure = False
        return False
    else:
        return True

# %%
def bfs_purning(data,root):

    prev_error = predict(X_and_Y_val,root)
    print "prev_error:", prev_error
    
    queue = []
    queue.append(root)
    while queue:
        currNode = queue.pop(0)
        flag = pruning(data,root,currNode,prev_error)
#         print "repr(currNode):",repr(currNode),"\nleft:",currNode.left,"\nright:",\
#         currNode.right,"\nsubset:",currNode.subset.shape,"\nlabel:",currNode.label,"\n"
#         #found the pruning node
        if(flag):
            print "--------------------\npruning node: ",repr(currNode), \
            "\nsubset:",currNode.subset.shape[0],"\nlabel:",currNode.label
            break
        if(currNode.left.pure==False):
            queue.append(currNode.left)
        if(currNode.right.pure==False):
            queue.append(currNode.right)

# %%
bfs_purning(X_and_Y_val,root)

validation_error = predict(X_and_Y_val,root)
print "validation_error: ",validation_error

testing_error = predict(X_and_Y_test,root)
print "testing_error: ",testing_error
# Out:
# prev_error: 0.179
# --------------------
# pruning node:  <__main__.DT_Node instance at 0x118c7f320>
# subset: 1319
# label: 0
# validation_error:  0.122
# testing_error:  0.117
