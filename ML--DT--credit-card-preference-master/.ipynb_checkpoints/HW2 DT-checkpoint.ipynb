# %%
from scipy import stats
import numpy as np
import matplotlib.pyplot as plt
import math
import random
import sys
import copy

# %%
# 1  import data 
# convert string to float
X_and_Y_train = np.loadtxt('data/pa2train.txt', delimiter=' ', usecols=range(23))
print "X_and_Y_train", X_and_Y_train.shape

X_and_Y_val = np.loadtxt('data/pa2validation.txt', delimiter=' ', usecols=range(23))
print "X_and_Y_val", X_and_Y_val.shape

X_and_Y_test = np.loadtxt('data/pa2test.txt', delimiter=' ', usecols=range(23))
print "X_and_Y_test is", X_and_Y_test.shape
# Out:
# X_and_Y_train (2000, 23)
# X_and_Y_val (1000, 23)
# X_and_Y_test is (1000, 23)

# %%
# passed in subset has 23 col, 22 features and  1 label
def calc_Entropy(feature,threshold,subset):

    counter1 = 0.0
    counter2 = 0.0
    counter3 = 0.0
    counter4 = 0.0
    trueNum = 0.0
    falseNum = 0.0
    totalNum = float(subset.shape[0])
    
    for i in range(subset.shape[0]):
        if(subset[i,feature] < threshold):
            trueNum+=1
            if (subset[i,22]==1):
                counter1+=1
            else:
                counter2+=1
        else:
            falseNum+=1
            if (subset[i,22]==1):
                counter3+=1
            else:
                counter4+=1
                
    prob1 = counter1/trueNum
    prob2 = counter2/trueNum
    prob3 = counter3/falseNum
    prob4 = counter4/falseNum
    probTrue = trueNum/totalNum
    probFalse = falseNum/totalNum
    
    if ((prob1==0 or prob2==0) and (prob3==0 or prob4==0)):
        entropy = 0
    elif ((prob1==0 or prob2==0) and prob3!=0 and prob4!=0):
        entropy = probFalse*(-prob3*np.log(prob3)-prob4*np.log(prob4))
    elif ((prob3==0 or prob4==0) and prob1!=0 and prob2!=0):
        entropy = probTrue*(-prob1*np.log(prob1)-prob2*np.log(prob2))
    else:
        entropy = probTrue*(-prob1*np.log(prob1)-prob2*np.log(prob2)) + \
        probFalse*(-prob3*np.log(prob3)-prob4*np.log(prob4))
    return entropy

# %%
# 2) Implement the DT
# data structure 
class DT_Node:
    def __init__(self,subset):
        self.left = None
        self.right =  None
        self.subset = subset
        self.threshold = None
        self.feature = None
        self.label = None
        self.pure = False

# %%
def findIndex(feature, threshold, sorted_by_feature):
    for i in range(sorted_by_feature.shape[0]-1):
        if ((sorted_by_feature[i,feature]) < threshold and (sorted_by_feature[i+1,feature]) > threshold):
            return i

# %%
# func: split the subset in a node into two subsets,left child node for the spliting rule 
# to be True and right child for the spliting rule ot be False
# notice that passed in node contains a subset, which is a 2D array, data by (feature+label)
# return: nothing
def splitRule(node):
    
    sorted_subset = copy.deepcopy(node.subset)
    #sort the subset data by all feature, axis=0 sort by col
    sorted_subset.sort(axis=0)
    
    Best_threshold=0
    Best_feature=0
    Min_entropy=sys.maxint

#     print "checking"
    for feature in range(sorted_subset.shape[1]-1):   #last col label not counted
        for data in range(sorted_subset.shape[0]-1):  
            #for all separable threshold, find its entropy
            if(sorted_subset[data,feature] != sorted_subset[data+1,feature]):
                #set threshold
                threshold = (sorted_subset[data,feature]+sorted_subset[data+1,feature])/2
                #calc entropy
                entropy = calc_Entropy(feature,threshold,node.subset)
                #update 
                if(entropy < Min_entropy):
                    Best_feature = feature
                    Best_threshold = threshold
                    Min_entropy = entropy
#                     print "Best_threshold,",Best_threshold, \
#                     "Best_feature",Best_feature,"Min_entropy",Min_entropy
                
    #   sorted by feature 
    sorted_by_feature = node.subset[np.argsort(node.subset[:,Best_feature])] 
    #   find spliting threshold index
    Best_threshold_index = findIndex(Best_feature, Best_threshold, sorted_by_feature)
    #   left child->True,  right child->false  of spliting rule
    left_subset = sorted_by_feature[:(Best_threshold_index+1),:] 
    right_subset = sorted_by_feature[(Best_threshold_index+1):,:]

    # set properties in the node
    node.threshold = Best_threshold
    node.feature = Best_feature
    node.left = DT_Node(left_subset)
    node.right = DT_Node(right_subset)

# %%
# func: check if the subset in a node is pure 
# return: Ture/False
def pureNode(node):
    label = node.subset[0,22]
    for i in range (node.subset.shape[0]):
        if(node.subset[i,22]!=label):
            return False
    return True

# %%
def ID3_helper(node):

    splitRule(node)
    
    if (pureNode(node.left)==True):  
        node.left.pure = True 
        node.left.label = node.left.subset[0,22]
    else:  
        #recursive call
        ID3_helper(node.left)
        
    if (pureNode(node.right)==True):
        node.right.pure = True 
        node.right.label = node.right.subset[0,22]
    else:  
        #recursive call
        ID3_helper(node.right)

# %%
def ID3_alg(X_and_Y_train):
    #inti   
    root = DT_Node(X_and_Y_train)
    #check if root can split 
    
    #call helper function to split the node recursively
    ID3_helper(root) 
    return root

# %%
# 3) call ID3 algorithm to build the tree

root = ID3_alg(X_and_Y_train)

# %%
# traverse the tree using bfs
def bfs(root):
    queue = []
    queue.append(root)
    while queue:
        currNode = queue.pop(0)
        if(currNode.pure == False):
            print "--------------------\n Internal node: ",repr(currNode),"\nleft child: ",repr(currNode.left),\
            "\nright child: ",repr(currNode.right),"\nsplit rule: feature",currNode.feature+1," < ",currNode.threshold,\
            "\nsubset size: ",currNode.subset.shape[0]
        else:
            print "--------------------\n Leaf Node: ",repr(currNode),"\n label: ",currNode.label,\
            "\subset size: ",currNode.subset.shape[0]
        if(currNode.left!=None):
            queue.append(currNode.left) 
        if(currNode.right!=None):
            queue.append(currNode.right)

# %% [markdown]
# # Part1 graphing the tree

# %%
# 4) call bfs to print the tree
bfs(root)
# Out:
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc77e8>
# left child:  <__main__.DT_Node instance at 0x118dc7ab8>
# right child:  <__main__.DT_Node instance at 0x118dc7cf8>
# split rule: feature 5  <  0.5
# subset size:  2000
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc7ab8>
# left child:  <__main__.DT_Node instance at 0x118dc7f38>
# right child:  <__main__.DT_Node instance at 0x118e01098>
# split rule: feature 1  <  415000.0
# subset size:  1319
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc7cf8>
# left child:  <__main__.DT_Node instance at 0x118dc87a0>
# right child:  <__main__.DT_Node instance at 0x118dc87e8>
# split rule: feature 5  <  1.5
# subset size:  681
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc7f38>
# left child:  <__main__.DT_Node instance at 0x118e01ef0>
# right child:  <__main__.DT_Node instance at 0x118e01710>
# split rule: feature 17  <  2506.5
# subset size:  1284
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118e01098>
# left child:  <__main__.DT_Node instance at 0x118dc8440>
# right child:  <__main__.DT_Node instance at 0x118dc8488>
# split rule: feature 21  <  208.0
# subset size:  35
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc87a0>
# left child:  <__main__.DT_Node instance at 0x118dc8830>
# right child:  <__main__.DT_Node instance at 0x118dc8878>
# split rule: feature 20  <  584.5
# subset size:  292
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc87e8>
# left child:  <__main__.DT_Node instance at 0x118defb00>
# right child:  <__main__.DT_Node instance at 0x118defb48>
# split rule: feature 21  <  2006.0
# subset size:  389
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118e01ef0>
# left child:  <__main__.DT_Node instance at 0x118e01cf8>
# right child:  <__main__.DT_Node instance at 0x118e01d40>
# split rule: feature 1  <  75000.0
# subset size:  704
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118e01710>
# left child:  <__main__.DT_Node instance at 0x118c64b90>
# right child:  <__main__.DT_Node instance at 0x118c64bd8>
# split rule: feature 1  <  25000.0
# subset size:  580
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dc8440>
#  label:  1.0 \subset size:  4
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc8488>
# left child:  <__main__.DT_Node instance at 0x118dc84d0>
# right child:  <__main__.DT_Node instance at 0x118dc8518>
# split rule: feature 17  <  2174.0
# subset size:  31
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc8830>
# left child:  <__main__.DT_Node instance at 0x118dc88c0>
# right child:  <__main__.DT_Node instance at 0x118dc8908>
# split rule: feature 12  <  231.5
# subset size:  134
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc8878>
# left child:  <__main__.DT_Node instance at 0x118def4d0>
# right child:  <__main__.DT_Node instance at 0x118def518>
# split rule: feature 12  <  1461.0
# subset size:  158
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118defb00>
# left child:  <__main__.DT_Node instance at 0x118defb90>
# right child:  <__main__.DT_Node instance at 0x118defbd8>
# split rule: feature 19  <  2476.0
# subset size:  232
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118defb48>
# left child:  <__main__.DT_Node instance at 0x118dd44d0>
# right child:  <__main__.DT_Node instance at 0x118dd4518>
# split rule: feature 19  <  13075.0
# subset size:  157
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118e01cf8>
# left child:  <__main__.DT_Node instance at 0x118e01ea8>
# right child:  <__main__.DT_Node instance at 0x118e017a0>
# split rule: feature 13  <  46620.5
# subset size:  393
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118e01d40>
# left child:  <__main__.DT_Node instance at 0x118c78ef0>
# right child:  <__main__.DT_Node instance at 0x118c78f38>
# split rule: feature 1  <  115000.0
# subset size:  311
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c64b90>
# left child:  <__main__.DT_Node instance at 0x118c64c20>
# right child:  <__main__.DT_Node instance at 0x118c64c68>
# split rule: feature 19  <  750.0
# subset size:  9
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c64bd8>
# left child:  <__main__.DT_Node instance at 0x118c64cb0>
# right child:  <__main__.DT_Node instance at 0x118c64cf8>
# split rule: feature 18  <  14935.5
# subset size:  571
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dc84d0>
#  label:  0.0 \subset size:  9
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc8518>
# left child:  <__main__.DT_Node instance at 0x118dc8560>
# right child:  <__main__.DT_Node instance at 0x118dc85a8>
# split rule: feature 22  <  2121.5
# subset size:  22
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc88c0>
# left child:  <__main__.DT_Node instance at 0x118dc8950>
# right child:  <__main__.DT_Node instance at 0x118dc8998>
# split rule: feature 4  <  2.5
# subset size:  54
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc8908>
# left child:  <__main__.DT_Node instance at 0x118dc8d40>
# right child:  <__main__.DT_Node instance at 0x118dc8d88>
# split rule: feature 12  <  316.0
# subset size:  80
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118def4d0>
# left child:  <__main__.DT_Node instance at 0x118def560>
# right child:  <__main__.DT_Node instance at 0x118def5a8>
# split rule: feature 2  <  1.5
# subset size:  22
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118def518>
# left child:  <__main__.DT_Node instance at 0x118def7a0>
# right child:  <__main__.DT_Node instance at 0x118def7e8>
# split rule: feature 21  <  1911.5
# subset size:  136
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118defb90>
# left child:  <__main__.DT_Node instance at 0x118defc20>
# right child:  <__main__.DT_Node instance at 0x118defc68>
# split rule: feature 19  <  2426.0
# subset size:  182
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118defbd8>
#  label:  1.0 \subset size:  50
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dd44d0>
#  label:  1.0 \subset size:  147
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd4518>
# left child:  <__main__.DT_Node instance at 0x118dd4560>
# right child:  <__main__.DT_Node instance at 0x118dd45a8>
# split rule: feature 19  <  13894.0
# subset size:  10
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118e01ea8>
# left child:  <__main__.DT_Node instance at 0x118e01cb0>
# right child:  <__main__.DT_Node instance at 0x118e01d88>
# split rule: feature 1  <  25000.0
# subset size:  349
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118e017a0>
# left child:  <__main__.DT_Node instance at 0x118c789e0>
# right child:  <__main__.DT_Node instance at 0x118c78a28>
# split rule: feature 2  <  1.5
# subset size:  44
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c78ef0>
# left child:  <__main__.DT_Node instance at 0x118c78f80>
# right child:  <__main__.DT_Node instance at 0x118c78fc8>
# split rule: feature 11  <  668.5
# subset size:  35
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c78f38>
# left child:  <__main__.DT_Node instance at 0x118c8e3b0>
# right child:  <__main__.DT_Node instance at 0x118c8e3f8>
# split rule: feature 1  <  125000.0
# subset size:  276
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c64c20>
#  label:  1.0 \subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c64c68>
#  label:  0.0 \subset size:  5
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c64cb0>
# left child:  <__main__.DT_Node instance at 0x118c64d40>
# right child:  <__main__.DT_Node instance at 0x118c64d88>
# split rule: feature 12  <  204348.0
# subset size:  532
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c64cf8>
#  label:  0.0 \subset size:  39
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dc8560>
#  label:  1.0 \subset size:  3
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc85a8>
# left child:  <__main__.DT_Node instance at 0x118dc85f0>
# right child:  <__main__.DT_Node instance at 0x118dc8638>
# split rule: feature 1  <  475000.0
# subset size:  19
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc8950>
# left child:  <__main__.DT_Node instance at 0x118dc89e0>
# right child:  <__main__.DT_Node instance at 0x118dc8a28>
# split rule: feature 1  <  190000.0
# subset size:  53
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dc8998>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dc8d40>
#  label:  0.0 \subset size:  3
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc8d88>
# left child:  <__main__.DT_Node instance at 0x118dc8dd0>
# right child:  <__main__.DT_Node instance at 0x118dc8e18>
# split rule: feature 18  <  6372.5
# subset size:  77
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118def560>
#  label:  1.0 \subset size:  10
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118def5a8>
# left child:  <__main__.DT_Node instance at 0x118def5f0>
# right child:  <__main__.DT_Node instance at 0x118def638>
# split rule: feature 13  <  701.5
# subset size:  12
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118def7a0>
#  label:  1.0 \subset size:  84
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118def7e8>
# left child:  <__main__.DT_Node instance at 0x118def830>
# right child:  <__main__.DT_Node instance at 0x118def878>
# split rule: feature 19  <  11929.0
# subset size:  52
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118defc20>
# left child:  <__main__.DT_Node instance at 0x118defcb0>
# right child:  <__main__.DT_Node instance at 0x118defcf8>
# split rule: feature 7  <  1.0
# subset size:  181
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118defc68>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dd4560>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dd45a8>
#  label:  1.0 \subset size:  9
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118e01cb0>
# left child:  <__main__.DT_Node instance at 0x118e01e18>
# right child:  <__main__.DT_Node instance at 0x118e018c0>
# split rule: feature 22  <  646.0
# subset size:  45
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118e01d88>
# left child:  <__main__.DT_Node instance at 0x118c7fc20>
# right child:  <__main__.DT_Node instance at 0x118c7fc68>
# split rule: feature 12  <  16815.5
# subset size:  304
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c789e0>
# left child:  <__main__.DT_Node instance at 0x118c78a70>
# right child:  <__main__.DT_Node instance at 0x118c78ab8>
# split rule: feature 11  <  58843.5
# subset size:  14
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c78a28>
# left child:  <__main__.DT_Node instance at 0x118c78c20>
# right child:  <__main__.DT_Node instance at 0x118c78c68>
# split rule: feature 11  <  50823.5
# subset size:  30
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c78f80>
# left child:  <__main__.DT_Node instance at 0x118c8e050>
# right child:  <__main__.DT_Node instance at 0x118c8e098>
# split rule: feature 6  <  1.0
# subset size:  11
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c78fc8>
# left child:  <__main__.DT_Node instance at 0x118c8e170>
# right child:  <__main__.DT_Node instance at 0x118c8e1b8>
# split rule: feature 17  <  1340.0
# subset size:  24
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c8e3b0>
#  label:  0.0 \subset size:  30
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c8e3f8>
# left child:  <__main__.DT_Node instance at 0x118c8e440>
# right child:  <__main__.DT_Node instance at 0x118c8e488>
# split rule: feature 22  <  2888.5
# subset size:  246
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c64d40>
# left child:  <__main__.DT_Node instance at 0x118c64dd0>
# right child:  <__main__.DT_Node instance at 0x118c64e18>
# split rule: feature 11  <  146305.0
# subset size:  499
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c64d88>
#  label:  0.0 \subset size:  33
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc85f0>
# left child:  <__main__.DT_Node instance at 0x118dc8680>
# right child:  <__main__.DT_Node instance at 0x118dc86c8>
# split rule: feature 19  <  14104.5
# subset size:  5
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc8638>
# left child:  <__main__.DT_Node instance at 0x118dc8710>
# right child:  <__main__.DT_Node instance at 0x118dc8758>
# split rule: feature 19  <  63135.0
# subset size:  14
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dc89e0>
#  label:  1.0 \subset size:  25
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc8a28>
# left child:  <__main__.DT_Node instance at 0x118dc8a70>
# right child:  <__main__.DT_Node instance at 0x118dc8ab8>
# split rule: feature 3  <  0.5
# subset size:  28
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc8dd0>
# left child:  <__main__.DT_Node instance at 0x118dc8e60>
# right child:  <__main__.DT_Node instance at 0x118dc8ea8>
# split rule: feature 3  <  0.5
# subset size:  72
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc8e18>
# left child:  <__main__.DT_Node instance at 0x118def440>
# right child:  <__main__.DT_Node instance at 0x118def488>
# split rule: feature 1  <  225000.0
# subset size:  5
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118def5f0>
# left child:  <__main__.DT_Node instance at 0x118def680>
# right child:  <__main__.DT_Node instance at 0x118def6c8>
# split rule: feature 15  <  903.5
# subset size:  9
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118def638>
#  label:  0.0 \subset size:  3
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118def830>
# left child:  <__main__.DT_Node instance at 0x118def8c0>
# right child:  <__main__.DT_Node instance at 0x118def908>
# split rule: feature 4  <  1.5
# subset size:  51
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118def878>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118defcb0>
#  label:  1.0 \subset size:  66
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118defcf8>
# left child:  <__main__.DT_Node instance at 0x118defd40>
# right child:  <__main__.DT_Node instance at 0x118defd88>
# split rule: feature 1  <  65000.0
# subset size:  115
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118e01e18>
# left child:  <__main__.DT_Node instance at 0x118c7f680>
# right child:  <__main__.DT_Node instance at 0x118c7f6c8>
# split rule: feature 18  <  1348.5
# subset size:  33
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118e018c0>
# left child:  <__main__.DT_Node instance at 0x118c7f9e0>
# right child:  <__main__.DT_Node instance at 0x118c7fa28>
# split rule: feature 17  <  1583.5
# subset size:  12
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7fc20>
# left child:  <__main__.DT_Node instance at 0x118c7fcb0>
# right child:  <__main__.DT_Node instance at 0x118c7fcf8>
# split rule: feature 22  <  1514.0
# subset size:  137
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7fc68>
# left child:  <__main__.DT_Node instance at 0x118c78680>
# right child:  <__main__.DT_Node instance at 0x118c786c8>
# split rule: feature 4  <  2.5
# subset size:  167
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c78a70>
# left child:  <__main__.DT_Node instance at 0x118c78b00>
# right child:  <__main__.DT_Node instance at 0x118c78b48>
# split rule: feature 13  <  49649.5
# subset size:  10
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c78ab8>
#  label:  0.0 \subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c78c20>
#  label:  0.0 \subset size:  12
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c78c68>
# left child:  <__main__.DT_Node instance at 0x118c78cb0>
# right child:  <__main__.DT_Node instance at 0x118c78cf8>
# split rule: feature 4  <  1.5
# subset size:  18
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c8e050>
#  label:  1.0 \subset size:  7
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c8e098>
# left child:  <__main__.DT_Node instance at 0x118c8e0e0>
# right child:  <__main__.DT_Node instance at 0x118c8e128>
# split rule: feature 1  <  85000.0
# subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c8e170>
#  label:  0.0 \subset size:  10
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c8e1b8>
# left child:  <__main__.DT_Node instance at 0x118c8e200>
# right child:  <__main__.DT_Node instance at 0x118c8e248>
# split rule: feature 17  <  1919.0
# subset size:  14
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c8e440>
# left child:  <__main__.DT_Node instance at 0x118c8e4d0>
# right child:  <__main__.DT_Node instance at 0x118c8e518>
# split rule: feature 11  <  19215.0
# subset size:  195
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c8e488>
# left child:  <__main__.DT_Node instance at 0x118c64560>
# right child:  <__main__.DT_Node instance at 0x118c645a8>
# split rule: feature 1  <  190000.0
# subset size:  51
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c64dd0>
# left child:  <__main__.DT_Node instance at 0x118c64e60>
# right child:  <__main__.DT_Node instance at 0x118c64ea8>
# split rule: feature 18  <  10835.5
# subset size:  454
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c64e18>
# left child:  <__main__.DT_Node instance at 0x118dc80e0>
# right child:  <__main__.DT_Node instance at 0x118dc8128>
# split rule: feature 19  <  4502.5
# subset size:  45
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dc8680>
#  label:  1.0 \subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dc86c8>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dc8710>
#  label:  0.0 \subset size:  12
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dc8758>
#  label:  1.0 \subset size:  2
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc8a70>
# left child:  <__main__.DT_Node instance at 0x118dc8b00>
# right child:  <__main__.DT_Node instance at 0x118dc8b48>
# split rule: feature 1  <  255000.0
# subset size:  3
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc8ab8>
# left child:  <__main__.DT_Node instance at 0x118dc8c20>
# right child:  <__main__.DT_Node instance at 0x118dc8c68>
# split rule: feature 22  <  839.5
# subset size:  25
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc8e60>
# left child:  <__main__.DT_Node instance at 0x118dc8ef0>
# right child:  <__main__.DT_Node instance at 0x118dc8f38>
# split rule: feature 1  <  25000.0
# subset size:  19
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc8ea8>
# left child:  <__main__.DT_Node instance at 0x118def170>
# right child:  <__main__.DT_Node instance at 0x118def1b8>
# split rule: feature 15  <  15900.0
# subset size:  53
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118def440>
#  label:  0.0 \subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118def488>
#  label:  1.0 \subset size:  1
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118def680>
# left child:  <__main__.DT_Node instance at 0x118def710>
# right child:  <__main__.DT_Node instance at 0x118def758>
# split rule: feature 21  <  967.5
# subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118def6c8>
#  label:  1.0 \subset size:  5
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118def8c0>
#  label:  1.0 \subset size:  24
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118def908>
# left child:  <__main__.DT_Node instance at 0x118def950>
# right child:  <__main__.DT_Node instance at 0x118def998>
# split rule: feature 17  <  8400.0
# subset size:  27
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118defd40>
# left child:  <__main__.DT_Node instance at 0x118defdd0>
# right child:  <__main__.DT_Node instance at 0x118defe18>
# split rule: feature 19  <  1867.0
# subset size:  74
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118defd88>
# left child:  <__main__.DT_Node instance at 0x118dd4050>
# right child:  <__main__.DT_Node instance at 0x118dd4098>
# split rule: feature 4  <  1.5
# subset size:  41
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7f680>
# left child:  <__main__.DT_Node instance at 0x118c7f710>
# right child:  <__main__.DT_Node instance at 0x118c7f758>
# split rule: feature 12  <  7776.0
# subset size:  19
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7f6c8>
#  label:  0.0 \subset size:  14
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7f9e0>
# left child:  <__main__.DT_Node instance at 0x118c7fa70>
# right child:  <__main__.DT_Node instance at 0x118c7fab8>
# split rule: feature 11  <  585.0
# subset size:  9
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7fa28>
#  label:  1.0 \subset size:  3
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7fcb0>
# left child:  <__main__.DT_Node instance at 0x118c7fd40>
# right child:  <__main__.DT_Node instance at 0x118c7fd88>
# split rule: feature 17  <  1641.0
# subset size:  107
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7fcf8>
#  label:  0.0 \subset size:  30
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c78680>
# left child:  <__main__.DT_Node instance at 0x118c78710>
# right child:  <__main__.DT_Node instance at 0x118c78758>
# split rule: feature 17  <  2503.0
# subset size:  166
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c786c8>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c78b00>
#  label:  1.0 \subset size:  6
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c78b48>
# left child:  <__main__.DT_Node instance at 0x118c78b90>
# right child:  <__main__.DT_Node instance at 0x118c78bd8>
# split rule: feature 16  <  28057.0
# subset size:  4
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c78cb0>
# left child:  <__main__.DT_Node instance at 0x118c78d40>
# right child:  <__main__.DT_Node instance at 0x118c78d88>
# split rule: feature 11  <  59051.0
# subset size:  6
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c78cf8>
# left child:  <__main__.DT_Node instance at 0x118c78e60>
# right child:  <__main__.DT_Node instance at 0x118c78ea8>
# split rule: feature 1  <  55000.0
# subset size:  12
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c8e0e0>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c8e128>
#  label:  0.0 \subset size:  3
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c8e200>
# left child:  <__main__.DT_Node instance at 0x118c8e290>
# right child:  <__main__.DT_Node instance at 0x118c8e2d8>
# split rule: feature 13  <  23252.0
# subset size:  10
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c8e248>
#  label:  0.0 \subset size:  4
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c8e4d0>
# left child:  <__main__.DT_Node instance at 0x118c8e560>
# right child:  <__main__.DT_Node instance at 0x118c8e5a8>
# split rule: feature 1  <  185000.0
# subset size:  180
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c8e518>
#  label:  0.0 \subset size:  15
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c64560>
# left child:  <__main__.DT_Node instance at 0x118c645f0>
# right child:  <__main__.DT_Node instance at 0x118c64638>
# split rule: feature 20  <  7026.0
# subset size:  9
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c645a8>
# left child:  <__main__.DT_Node instance at 0x118c64710>
# right child:  <__main__.DT_Node instance at 0x118c64758>
# split rule: feature 11  <  49829.0
# subset size:  42
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c64e60>
# left child:  <__main__.DT_Node instance at 0x118c64ef0>
# right child:  <__main__.DT_Node instance at 0x118c64f38>
# split rule: feature 21  <  809.5
# subset size:  443
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c64ea8>
# left child:  <__main__.DT_Node instance at 0x118dccf80>
# right child:  <__main__.DT_Node instance at 0x118dccfc8>
# split rule: feature 13  <  14402.0
# subset size:  11
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc80e0>
# left child:  <__main__.DT_Node instance at 0x118dc8170>
# right child:  <__main__.DT_Node instance at 0x118dc81b8>
# split rule: feature 15  <  95643.0
# subset size:  10
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc8128>
# left child:  <__main__.DT_Node instance at 0x118dc8290>
# right child:  <__main__.DT_Node instance at 0x118dc82d8>
# split rule: feature 19  <  9000.0
# subset size:  35
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dc8b00>
#  label:  1.0 \subset size:  1
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc8b48>
# left child:  <__main__.DT_Node instance at 0x118dc8b90>
# right child:  <__main__.DT_Node instance at 0x118dc8bd8>
# split rule: feature 1  <  290000.0
# subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dc8c20>
#  label:  1.0 \subset size:  22
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc8c68>
# left child:  <__main__.DT_Node instance at 0x118dc8cb0>
# right child:  <__main__.DT_Node instance at 0x118dc8cf8>
# split rule: feature 1  <  220000.0
# subset size:  3
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dc8ef0>
#  label:  1.0 \subset size:  6
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc8f38>
# left child:  <__main__.DT_Node instance at 0x118dc8f80>
# right child:  <__main__.DT_Node instance at 0x118dc8fc8>
# split rule: feature 8  <  1.0
# subset size:  13
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118def170>
#  label:  1.0 \subset size:  32
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118def1b8>
# left child:  <__main__.DT_Node instance at 0x118def200>
# right child:  <__main__.DT_Node instance at 0x118def248>
# split rule: feature 19  <  2555.5
# subset size:  21
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118def710>
#  label:  0.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118def758>
#  label:  1.0 \subset size:  2
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118def950>
# left child:  <__main__.DT_Node instance at 0x118def9e0>
# right child:  <__main__.DT_Node instance at 0x118defa28>
# split rule: feature 15  <  29380.5
# subset size:  26
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118def998>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118defdd0>
#  label:  1.0 \subset size:  64
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118defe18>
# left child:  <__main__.DT_Node instance at 0x118defe60>
# right child:  <__main__.DT_Node instance at 0x118defea8>
# split rule: feature 2  <  1.5
# subset size:  10
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dd4050>
#  label:  1.0 \subset size:  17
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd4098>
# left child:  <__main__.DT_Node instance at 0x118dd40e0>
# right child:  <__main__.DT_Node instance at 0x118dd4128>
# split rule: feature 14  <  455.5
# subset size:  24
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7f710>
#  label:  0.0 \subset size:  7
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7f758>
# left child:  <__main__.DT_Node instance at 0x118c7f7a0>
# right child:  <__main__.DT_Node instance at 0x118c7f7e8>
# split rule: feature 22  <  97.5
# subset size:  12
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7fa70>
#  label:  1.0 \subset size:  2
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7fab8>
# left child:  <__main__.DT_Node instance at 0x118c7fb00>
# right child:  <__main__.DT_Node instance at 0x118c7fb48>
# split rule: feature 12  <  3124.0
# subset size:  7
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7fd40>
# left child:  <__main__.DT_Node instance at 0x118c7fdd0>
# right child:  <__main__.DT_Node instance at 0x118c7fe18>
# split rule: feature 11  <  46792.5
# subset size:  95
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7fd88>
# left child:  <__main__.DT_Node instance at 0x118c784d0>
# right child:  <__main__.DT_Node instance at 0x118c78518>
# split rule: feature 14  <  5583.0
# subset size:  12
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c78710>
# left child:  <__main__.DT_Node instance at 0x118c787a0>
# right child:  <__main__.DT_Node instance at 0x118c787e8>
# split rule: feature 14  <  25530.0
# subset size:  165
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c78758>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c78b90>
#  label:  0.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c78bd8>
#  label:  1.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c78d40>
#  label:  1.0 \subset size:  3
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c78d88>
# left child:  <__main__.DT_Node instance at 0x118c78dd0>
# right child:  <__main__.DT_Node instance at 0x118c78e18>
# split rule: feature 11  <  59905.5
# subset size:  3
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c78e60>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c78ea8>
#  label:  0.0 \subset size:  11
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c8e290>
# left child:  <__main__.DT_Node instance at 0x118c8e320>
# right child:  <__main__.DT_Node instance at 0x118c8e368>
# split rule: feature 12  <  12973.0
# subset size:  6
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c8e2d8>
#  label:  1.0 \subset size:  4
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c8e560>
# left child:  <__main__.DT_Node instance at 0x118c8e5f0>
# right child:  <__main__.DT_Node instance at 0x118c8e638>
# split rule: feature 22  <  1189.0
# subset size:  52
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c8e5a8>
# left child:  <__main__.DT_Node instance at 0x118c8ecb0>
# right child:  <__main__.DT_Node instance at 0x118c8ecf8>
# split rule: feature 20  <  1728.0
# subset size:  128
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c645f0>
# left child:  <__main__.DT_Node instance at 0x118c64680>
# right child:  <__main__.DT_Node instance at 0x118c646c8>
# split rule: feature 3  <  0.5
# subset size:  7
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c64638>
#  label:  0.0 \subset size:  2
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c64710>
# left child:  <__main__.DT_Node instance at 0x118c647a0>
# right child:  <__main__.DT_Node instance at 0x118c647e8>
# split rule: feature 22  <  10234.5
# subset size:  40
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c64758>
#  label:  1.0 \subset size:  2
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c64ef0>
# left child:  <__main__.DT_Node instance at 0x118c64f80>
# right child:  <__main__.DT_Node instance at 0x118c64fc8>
# split rule: feature 17  <  3153.5
# subset size:  95
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c64f38>
# left child:  <__main__.DT_Node instance at 0x118dcc680>
# right child:  <__main__.DT_Node instance at 0x118dcc6c8>
# split rule: feature 11  <  1809.5
# subset size:  348
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dccf80>
#  label:  0.0 \subset size:  6
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dccfc8>
# left child:  <__main__.DT_Node instance at 0x118dc8050>
# right child:  <__main__.DT_Node instance at 0x118dc8098>
# split rule: feature 10  <  1.0
# subset size:  5
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc8170>
# left child:  <__main__.DT_Node instance at 0x118dc8200>
# right child:  <__main__.DT_Node instance at 0x118dc8248>
# split rule: feature 4  <  1.5
# subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dc81b8>
#  label:  1.0 \subset size:  6
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc8290>
# left child:  <__main__.DT_Node instance at 0x118dc8320>
# right child:  <__main__.DT_Node instance at 0x118dc8368>
# split rule: feature 16  <  194572.5
# subset size:  29
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc82d8>
# left child:  <__main__.DT_Node instance at 0x118dc83b0>
# right child:  <__main__.DT_Node instance at 0x118dc83f8>
# split rule: feature 9  <  1.0
# subset size:  6
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dc8b90>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dc8bd8>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dc8cb0>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dc8cf8>
#  label:  1.0 \subset size:  2
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dc8f80>
# left child:  <__main__.DT_Node instance at 0x118def050>
# right child:  <__main__.DT_Node instance at 0x118def098>
# split rule: feature 1  <  250000.0
# subset size:  9
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dc8fc8>
#  label:  1.0 \subset size:  4
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118def200>
# left child:  <__main__.DT_Node instance at 0x118def290>
# right child:  <__main__.DT_Node instance at 0x118def2d8>
# split rule: feature 21  <  890.5
# subset size:  12
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118def248>
#  label:  1.0 \subset size:  9
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118def9e0>
# left child:  <__main__.DT_Node instance at 0x118defa70>
# right child:  <__main__.DT_Node instance at 0x118defab8>
# split rule: feature 1  <  45000.0
# subset size:  10
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118defa28>
#  label:  1.0 \subset size:  16
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118defe60>
#  label:  1.0 \subset size:  6
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118defea8>
# left child:  <__main__.DT_Node instance at 0x118defef0>
# right child:  <__main__.DT_Node instance at 0x118deff38>
# split rule: feature 1  <  40000.0
# subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dd40e0>
#  label:  0.0 \subset size:  2
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd4128>
# left child:  <__main__.DT_Node instance at 0x118dd4170>
# right child:  <__main__.DT_Node instance at 0x118dd41b8>
# split rule: feature 1  <  335000.0
# subset size:  22
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7f7a0>
# left child:  <__main__.DT_Node instance at 0x118c7f830>
# right child:  <__main__.DT_Node instance at 0x118c7f878>
# split rule: feature 13  <  4860.0
# subset size:  7
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7f7e8>
# left child:  <__main__.DT_Node instance at 0x118c7f950>
# right child:  <__main__.DT_Node instance at 0x118c7f998>
# split rule: feature 11  <  7900.5
# subset size:  5
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7fb00>
#  label:  0.0 \subset size:  4
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7fb48>
# left child:  <__main__.DT_Node instance at 0x118c7fb90>
# right child:  <__main__.DT_Node instance at 0x118c7fbd8>
# split rule: feature 11  <  13850.5
# subset size:  3
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7fdd0>
# left child:  <__main__.DT_Node instance at 0x118c7fe60>
# right child:  <__main__.DT_Node instance at 0x118c7fea8>
# split rule: feature 21  <  198.0
# subset size:  94
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7fe18>
#  label:  1.0 \subset size:  1
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c784d0>
# left child:  <__main__.DT_Node instance at 0x118c78560>
# right child:  <__main__.DT_Node instance at 0x118c785a8>
# split rule: feature 15  <  1027.0
# subset size:  8
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c78518>
#  label:  1.0 \subset size:  4
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c787a0>
# left child:  <__main__.DT_Node instance at 0x118c78830>
# right child:  <__main__.DT_Node instance at 0x118c78878>
# split rule: feature 16  <  21960.5
# subset size:  74
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c787e8>
#  label:  0.0 \subset size:  91
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c78dd0>
#  label:  0.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c78e18>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c8e320>
#  label:  1.0 \subset size:  3
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c8e368>
#  label:  0.0 \subset size:  3
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c8e5f0>
# left child:  <__main__.DT_Node instance at 0x118c8e680>
# right child:  <__main__.DT_Node instance at 0x118c8e6c8>
# split rule: feature 22  <  656.5
# subset size:  41
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c8e638>
#  label:  0.0 \subset size:  11
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c8ecb0>
# left child:  <__main__.DT_Node instance at 0x118c8ed40>
# right child:  <__main__.DT_Node instance at 0x118c8ed88>
# split rule: feature 16  <  2474.5
# subset size:  106
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c8ecf8>
#  label:  0.0 \subset size:  22
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c64680>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c646c8>
#  label:  1.0 \subset size:  6
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c647a0>
# left child:  <__main__.DT_Node instance at 0x118c64830>
# right child:  <__main__.DT_Node instance at 0x118c64878>
# split rule: feature 12  <  4137.5
# subset size:  24
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c647e8>
# left child:  <__main__.DT_Node instance at 0x118c64950>
# right child:  <__main__.DT_Node instance at 0x118c64998>
# split rule: feature 15  <  10768.0
# subset size:  16
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c64f80>
# left child:  <__main__.DT_Node instance at 0x118dcc050>
# right child:  <__main__.DT_Node instance at 0x118dcc098>
# split rule: feature 10  <  1.0
# subset size:  18
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c64fc8>
# left child:  <__main__.DT_Node instance at 0x118dcc290>
# right child:  <__main__.DT_Node instance at 0x118dcc2d8>
# split rule: feature 19  <  35025.5
# subset size:  77
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dcc680>
# left child:  <__main__.DT_Node instance at 0x118dcc710>
# right child:  <__main__.DT_Node instance at 0x118dcc758>
# split rule: feature 16  <  4690.5
# subset size:  22
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dcc6c8>
# left child:  <__main__.DT_Node instance at 0x118dcc8c0>
# right child:  <__main__.DT_Node instance at 0x118dcc908>
# split rule: feature 21  <  4002.5
# subset size:  326
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dc8050>
#  label:  1.0 \subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dc8098>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dc8200>
#  label:  0.0 \subset size:  3
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dc8248>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dc8320>
#  label:  0.0 \subset size:  28
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dc8368>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dc83b0>
#  label:  1.0 \subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dc83f8>
#  label:  0.0 \subset size:  2
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118def050>
# left child:  <__main__.DT_Node instance at 0x118def0e0>
# right child:  <__main__.DT_Node instance at 0x118def128>
# split rule: feature 13  <  36038.5
# subset size:  8
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118def098>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118def290>
#  label:  1.0 \subset size:  4
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118def2d8>
# left child:  <__main__.DT_Node instance at 0x118def320>
# right child:  <__main__.DT_Node instance at 0x118def368>
# split rule: feature 21  <  2500.0
# subset size:  8
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118defa70>
#  label:  1.0 \subset size:  8
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118defab8>
#  label:  0.0 \subset size:  2
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118defef0>
# left child:  <__main__.DT_Node instance at 0x118deff80>
# right child:  <__main__.DT_Node instance at 0x118deffc8>
# split rule: feature 11  <  19641.0
# subset size:  3
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118deff38>
#  label:  1.0 \subset size:  1
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd4170>
# left child:  <__main__.DT_Node instance at 0x118dd4200>
# right child:  <__main__.DT_Node instance at 0x118dd4248>
# split rule: feature 8  <  4.5
# subset size:  21
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dd41b8>
#  label:  0.0 \subset size:  1
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7f830>
# left child:  <__main__.DT_Node instance at 0x118c7f8c0>
# right child:  <__main__.DT_Node instance at 0x118c7f908>
# split rule: feature 3  <  0.5
# subset size:  3
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7f878>
#  label:  1.0 \subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7f950>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7f998>
#  label:  0.0 \subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7fb90>
#  label:  1.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7fbd8>
#  label:  0.0 \subset size:  1
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7fe60>
# left child:  <__main__.DT_Node instance at 0x118c7fef0>
# right child:  <__main__.DT_Node instance at 0x118c7ff38>
# split rule: feature 6  <  1.0
# subset size:  46
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7fea8>
# left child:  <__main__.DT_Node instance at 0x118c783b0>
# right child:  <__main__.DT_Node instance at 0x118c783f8>
# split rule: feature 22  <  1206.5
# subset size:  48
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c78560>
# left child:  <__main__.DT_Node instance at 0x118c785f0>
# right child:  <__main__.DT_Node instance at 0x118c78638>
# split rule: feature 13  <  825.5
# subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c785a8>
#  label:  0.0 \subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c78830>
#  label:  0.0 \subset size:  51
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c78878>
# left child:  <__main__.DT_Node instance at 0x118c788c0>
# right child:  <__main__.DT_Node instance at 0x118c78908>
# split rule: feature 15  <  21774.5
# subset size:  23
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c8e680>
# left child:  <__main__.DT_Node instance at 0x118c8e710>
# right child:  <__main__.DT_Node instance at 0x118c8e758>
# split rule: feature 15  <  16077.5
# subset size:  33
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c8e6c8>
# left child:  <__main__.DT_Node instance at 0x118c8eb90>
# right child:  <__main__.DT_Node instance at 0x118c8ebd8>
# split rule: feature 1  <  155000.0
# subset size:  8
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c8ed40>
# left child:  <__main__.DT_Node instance at 0x118c8edd0>
# right child:  <__main__.DT_Node instance at 0x118c8ee18>
# split rule: feature 1  <  205000.0
# subset size:  95
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c8ed88>
# left child:  <__main__.DT_Node instance at 0x118c64440>
# right child:  <__main__.DT_Node instance at 0x118c64488>
# split rule: feature 11  <  10893.0
# subset size:  11
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c64830>
#  label:  0.0 \subset size:  18
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c64878>
# left child:  <__main__.DT_Node instance at 0x118c648c0>
# right child:  <__main__.DT_Node instance at 0x118c64908>
# split rule: feature 4  <  1.5
# subset size:  6
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c64950>
# left child:  <__main__.DT_Node instance at 0x118c649e0>
# right child:  <__main__.DT_Node instance at 0x118c64a28>
# split rule: feature 1  <  330000.0
# subset size:  9
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c64998>
# left child:  <__main__.DT_Node instance at 0x118c64b00>
# right child:  <__main__.DT_Node instance at 0x118c64b48>
# split rule: feature 14  <  98920.5
# subset size:  7
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dcc050>
# ...
# split rule: feature 12  <  48957.0
# subset size:  6
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dcc950>
# left child:  <__main__.DT_Node instance at 0x118dcc9e0>
# right child:  <__main__.DT_Node instance at 0x118dcca28>
# split rule: feature 16  <  38724.0
# subset size:  181
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dcc998>
# left child:  <__main__.DT_Node instance at 0x118dccd40>
# right child:  <__main__.DT_Node instance at 0x118dccd88>
# split rule: feature 16  <  99997.0
# subset size:  33
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118def3b0>
#  label:  0.0 \subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118def3f8>
#  label:  1.0 \subset size:  1
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd4290>
# left child:  <__main__.DT_Node instance at 0x118dd4320>
# right child:  <__main__.DT_Node instance at 0x118dd4368>
# split rule: feature 15  <  29979.5
# subset size:  11
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dd42d8>
#  label:  1.0 \subset size:  9
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c7ff80>
#  label:  1.0 \subset size:  1
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c7ffc8>
# left child:  <__main__.DT_Node instance at 0x118c78050>
# right child:  <__main__.DT_Node instance at 0x118c78098>
# split rule: feature 22  <  1359.5
# subset size:  40
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c78290>
#  label:  1.0 \subset size:  2
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c782d8>
# left child:  <__main__.DT_Node instance at 0x118c78320>
# right child:  <__main__.DT_Node instance at 0x118c78368>
# split rule: feature 11  <  1328.0
# subset size:  3
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c78440>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c78488>
#  label:  0.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c78950>
#  label:  0.0 \subset size:  20
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c78998>
#  label:  1.0 \subset size:  1
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c8e7a0>
# left child:  <__main__.DT_Node instance at 0x118c8e830>
# right child:  <__main__.DT_Node instance at 0x118c8e878>
# split rule: feature 1  <  150000.0
# subset size:  22
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c8e7e8>
#  label:  0.0 \subset size:  9
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c8ec20>
#  label:  1.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c8ec68>
#  label:  0.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c8ee60>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c8eea8>
#  label:  0.0 \subset size:  40
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c8eef0>
# left child:  <__main__.DT_Node instance at 0x118c8ef80>
# right child:  <__main__.DT_Node instance at 0x118c8efc8>
# split rule: feature 4  <  1.5
# subset size:  52
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c8ef38>
#  label:  1.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c644d0>
#  label:  1.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c64518>
#  label:  0.0 \subset size:  6
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c64a70>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c64ab8>
#  label:  1.0 \subset size:  6
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dcc200>
#  label:  1.0 \subset size:  5
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dcc248>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dcc3b0>
#  label:  0.0 \subset size:  45
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dcc3f8>
# left child:  <__main__.DT_Node instance at 0x118dcc440>
# right child:  <__main__.DT_Node instance at 0x118dcc488>
# split rule: feature 18  <  3745.0
# subset size:  28
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dcc830>
#  label:  0.0 \subset size:  5
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dcc878>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dcc9e0>
#  label:  0.0 \subset size:  111
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dcca28>
# left child:  <__main__.DT_Node instance at 0x118dcca70>
# right child:  <__main__.DT_Node instance at 0x118dccab8>
# split rule: feature 1  <  85000.0
# subset size:  70
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dccd40>
# left child:  <__main__.DT_Node instance at 0x118dccdd0>
# right child:  <__main__.DT_Node instance at 0x118dcce18>
# split rule: feature 13  <  93450.5
# subset size:  23
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dccd88>
#  label:  0.0 \subset size:  10
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd4320>
# left child:  <__main__.DT_Node instance at 0x118dd43b0>
# right child:  <__main__.DT_Node instance at 0x118dd43f8>
# split rule: feature 3  <  0.5
# subset size:  8
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dd4368>
# left child:  <__main__.DT_Node instance at 0x118dd4440>
# right child:  <__main__.DT_Node instance at 0x118dd4488>
# split rule: feature 15  <  52494.0
# subset size:  3
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c78050>
# left child:  <__main__.DT_Node instance at 0x118c780e0>
# right child:  <__main__.DT_Node instance at 0x118c78128>
# split rule: feature 11  <  2973.0
# subset size:  39
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c78098>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c78320>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c78368>
#  label:  0.0 \subset size:  2
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c8e830>
# left child:  <__main__.DT_Node instance at 0x118c8e8c0>
# right child:  <__main__.DT_Node instance at 0x118c8e908>
# split rule: feature 1  <  135000.0
# subset size:  11
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c8e878>
# left child:  <__main__.DT_Node instance at 0x118c8e9e0>
# right child:  <__main__.DT_Node instance at 0x118c8ea28>
# split rule: feature 11  <  1240.0
# subset size:  11
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c8ef80>
# left child:  <__main__.DT_Node instance at 0x118c64050>
# right child:  <__main__.DT_Node instance at 0x118c64098>
# split rule: feature 11  <  237.5
# subset size:  26
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c8efc8>
# left child:  <__main__.DT_Node instance at 0x118c64170>
# right child:  <__main__.DT_Node instance at 0x118c641b8>
# split rule: feature 1  <  330000.0
# subset size:  26
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dcc440>
# left child:  <__main__.DT_Node instance at 0x118dcc4d0>
# right child:  <__main__.DT_Node instance at 0x118dcc518>
# split rule: feature 3  <  0.5
# subset size:  8
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dcc488>
#  label:  0.0 \subset size:  20
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dcca70>
# left child:  <__main__.DT_Node instance at 0x118dccb00>
# right child:  <__main__.DT_Node instance at 0x118dccb48>
# split rule: feature 18  <  500.0
# subset size:  26
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dccab8>
#  label:  0.0 \subset size:  44
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dccdd0>
# left child:  <__main__.DT_Node instance at 0x118dcce60>
# right child:  <__main__.DT_Node instance at 0x118dccea8>
# split rule: feature 11  <  4412.0
# subset size:  17
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dcce18>
# left child:  <__main__.DT_Node instance at 0x118dccef0>
# right child:  <__main__.DT_Node instance at 0x118dccf38>
# split rule: feature 14  <  104732.5
# subset size:  6
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dd43b0>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dd43f8>
#  label:  1.0 \subset size:  7
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dd4440>
#  label:  0.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dd4488>
#  label:  1.0 \subset size:  1
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c780e0>
# left child:  <__main__.DT_Node instance at 0x118c78170>
# right child:  <__main__.DT_Node instance at 0x118c781b8>
# split rule: feature 11  <  785.5
# subset size:  19
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c78128>
#  label:  0.0 \subset size:  20
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c8e8c0>
# left child:  <__main__.DT_Node instance at 0x118c8e950>
# right child:  <__main__.DT_Node instance at 0x118c8e998>
# split rule: feature 11  <  2790.0
# subset size:  3
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c8e908>
#  label:  0.0 \subset size:  8
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c8e9e0>
# left child:  <__main__.DT_Node instance at 0x118c8ea70>
# right child:  <__main__.DT_Node instance at 0x118c8eab8>
# split rule: feature 1  <  175000.0
# subset size:  9
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c8ea28>
#  label:  1.0 \subset size:  2
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c64050>
# left child:  <__main__.DT_Node instance at 0x118c640e0>
# right child:  <__main__.DT_Node instance at 0x118c64128>
# split rule: feature 11  <  50.5
# subset size:  10
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c64098>
#  label:  0.0 \subset size:  16
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c64170>
# left child:  <__main__.DT_Node instance at 0x118c64200>
# right child:  <__main__.DT_Node instance at 0x118c64248>
# split rule: feature 2  <  1.5
# subset size:  24
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c641b8>
#  label:  1.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dcc4d0>
#  label:  1.0 \subset size:  2
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dcc518>
# left child:  <__main__.DT_Node instance at 0x118dcc560>
# right child:  <__main__.DT_Node instance at 0x118dcc5a8>
# split rule: feature 11  <  94094.5
# subset size:  6
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dccb00>
#  label:  1.0 \subset size:  2
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dccb48>
# left child:  <__main__.DT_Node instance at 0x118dccb90>
# right child:  <__main__.DT_Node instance at 0x118dccbd8>
# split rule: feature 1  <  75000.0
# subset size:  24
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dcce60>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dccea8>
#  label:  0.0 \subset size:  16
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dccef0>
#  label:  1.0 \subset size:  5
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dccf38>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c78170>
#  label:  0.0 \subset size:  13
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c781b8>
# left child:  <__main__.DT_Node instance at 0x118c78200>
# right child:  <__main__.DT_Node instance at 0x118c78248>
# split rule: feature 12  <  767.5
# subset size:  6
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c8e950>
#  label:  0.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c8e998>
#  label:  1.0 \subset size:  1
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c8ea70>
# left child:  <__main__.DT_Node instance at 0x118c8eb00>
# right child:  <__main__.DT_Node instance at 0x118c8eb48>
# split rule: feature 11  <  512.5
# subset size:  5
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c8eab8>
#  label:  0.0 \subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c640e0>
#  label:  0.0 \subset size:  9
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c64128>
#  label:  1.0 \subset size:  1
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c64200>
# left child:  <__main__.DT_Node instance at 0x118c64290>
# right child:  <__main__.DT_Node instance at 0x118c642d8>
# split rule: feature 11  <  195.0
# subset size:  6
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c64248>
# left child:  <__main__.DT_Node instance at 0x118c64320>
# right child:  <__main__.DT_Node instance at 0x118c64368>
# split rule: feature 12  <  1246.5
# subset size:  18
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dcc560>
#  label:  0.0 \subset size:  5
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dcc5a8>
#  label:  1.0 \subset size:  1
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dccb90>
# left child:  <__main__.DT_Node instance at 0x118dccc20>
# right child:  <__main__.DT_Node instance at 0x118dccc68>
# split rule: feature 16  <  38969.0
# subset size:  21
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118dccbd8>
# left child:  <__main__.DT_Node instance at 0x118dcccb0>
# right child:  <__main__.DT_Node instance at 0x118dcccf8>
# split rule: feature 2  <  1.5
# subset size:  3
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c78200>
#  label:  1.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c78248>
#  label:  0.0 \subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c8eb00>
#  label:  1.0 \subset size:  3
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c8eb48>
#  label:  0.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c64290>
#  label:  1.0 \subset size:  3
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c642d8>
#  label:  0.0 \subset size:  3
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c64320>
#  label:  0.0 \subset size:  14
# --------------------
#  Internal node:  <__main__.DT_Node instance at 0x118c64368>
# left child:  <__main__.DT_Node instance at 0x118c643b0>
# right child:  <__main__.DT_Node instance at 0x118c643f8>
# split rule: feature 3  <  0.5
# subset size:  4
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dccc20>
#  label:  1.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dccc68>
#  label:  0.0 \subset size:  20
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dcccb0>
#  label:  0.0 \subset size:  1
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118dcccf8>
#  label:  1.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c643b0>
#  label:  0.0 \subset size:  2
# --------------------
#  Leaf Node:  <__main__.DT_Node instance at 0x118c643f8>
#  label:  1.0 \subset size:  2

# %% [markdown]
# # Part2  training and test error

# %%
#purpose: func for predicting error given data
#return: error
def predict(data,root):

    wrong_counter = 0.0
    data_size = data.shape[0]
    
    for i in range(data_size):  
        currNode = root
        while(currNode.pure==False):
            if(data[i,currNode.feature] < currNode.threshold):
                currNode=currNode.left
            else:
                currNode=currNode.right
                
        if(currNode.label != data[i,22]):
            wrong_counter+=1

    error = wrong_counter/float(data_size)
    return error

# %%
training_error = predict(X_and_Y_train,root)
print "training_error: ",training_error

testing_error = predict(X_and_Y_test,root)
print "testing_error: ",testing_error

val_error = predict(X_and_Y_val,root)
print "validation_error: ",val_error
# Out:
# training_error:  0.0
# testing_error:  0.173
# validation_error:  0.179

# %% [markdown]
# # Part3  validation and test error after 1st and 2nd round pruning

# %%
def calcMajorityLabel(data):
    counts = np.bincount([int(i) for i in data[:,22]])
    return np.argmax(counts)

# %%
#purpose: for each node v in the tree, replace the tree starting at 
#root v by single node that predicts the majority label in v to get 
#tree T', if error(T')<=error(T), replace T by T'
def pruning(data,root,currNode,prev_error):
  
    #calculate majority
    majority_label = calcMajorityLabel(data)
      
    #replace the node by changing property inside the node
    currNode.label = majority_label
    currNode.pure = True
    
    after_error = predict(data,root)
    
    #change back since no progress made
    if(after_error > prev_error):
        currNode.label = None
        currNode.pure = False
        return False
    else:
        return True

# %%
def bfs_purning(data,root):

    prev_error = predict(X_and_Y_val,root)
    print "prev_error:", prev_error
    
    queue = []
    queue.append(root)
    while queue:
        currNode = queue.pop(0)
        flag = pruning(data,root,currNode,prev_error)
#         print "repr(currNode):",repr(currNode),"\nleft:",currNode.left,"\nright:",\
#         currNode.right,"\nsubset:",currNode.subset.shape,"\nlabel:",currNode.label,"\n"
#         #found the pruning node
        if(flag):
            print "--------------------\npruning node: ",repr(currNode), \
            "\nsubset:",currNode.subset.shape[0],"\nlabel:",currNode.label
            break
        if(currNode.left.pure==False):
            queue.append(currNode.left)
        if(currNode.right.pure==False):
            queue.append(currNode.right)

# %%
bfs_purning(X_and_Y_val,root)

validation_error = predict(X_and_Y_val,root)
print "validation_error: ",validation_error

testing_error = predict(X_and_Y_test,root)
print "testing_error: ",testing_error
# Out:
# prev_error: 0.122
# repr(currNode): <__main__.DT_Node instance at 0x118dc77e8>
# left: <__main__.DT_Node instance at 0x118dc7ab8>
# right: <__main__.DT_Node instance at 0x118dc7cf8>
# subset: (2000, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118dc7cf8>
# left: <__main__.DT_Node instance at 0x118dc87a0>
# right: <__main__.DT_Node instance at 0x118dc87e8>
# subset: (681, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118dc87a0>
# left: <__main__.DT_Node instance at 0x118dc8830>
# right: <__main__.DT_Node instance at 0x118dc8878>
# subset: (292, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118dc87e8>
# left: <__main__.DT_Node instance at 0x118defb00>
# right: <__main__.DT_Node instance at 0x118defb48>
# subset: (389, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118dc8830>
# left: <__main__.DT_Node instance at 0x118dc88c0>
# right: <__main__.DT_Node instance at 0x118dc8908>
# subset: (134, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118dc8878>
# left: <__main__.DT_Node instance at 0x118def4d0>
# right: <__main__.DT_Node instance at 0x118def518>
# subset: (158, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118defb00>
# left: <__main__.DT_Node instance at 0x118defb90>
# right: <__main__.DT_Node instance at 0x118defbd8>
# subset: (232, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118defb48>
# left: <__main__.DT_Node instance at 0x118dd44d0>
# right: <__main__.DT_Node instance at 0x118dd4518>
# subset: (157, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118dc88c0>
# left: <__main__.DT_Node instance at 0x118dc8950>
# right: <__main__.DT_Node instance at 0x118dc8998>
# subset: (54, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118dc8908>
# left: <__main__.DT_Node instance at 0x118dc8d40>
# right: <__main__.DT_Node instance at 0x118dc8d88>
# subset: (80, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118def4d0>
# left: <__main__.DT_Node instance at 0x118def560>
# right: <__main__.DT_Node instance at 0x118def5a8>
# subset: (22, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118def518>
# left: <__main__.DT_Node instance at 0x118def7a0>
# right: <__main__.DT_Node instance at 0x118def7e8>
# subset: (136, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118defb90>
# left: <__main__.DT_Node instance at 0x118defc20>
# right: <__main__.DT_Node instance at 0x118defc68>
# subset: (182, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118dd4518>
# left: <__main__.DT_Node instance at 0x118dd4560>
# right: <__main__.DT_Node instance at 0x118dd45a8>
# subset: (10, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118dc8950>
# left: <__main__.DT_Node instance at 0x118dc89e0>
# right: <__main__.DT_Node instance at 0x118dc8a28>
# subset: (53, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118dc8d88>
# left: <__main__.DT_Node instance at 0x118dc8dd0>
# right: <__main__.DT_Node instance at 0x118dc8e18>
# subset: (77, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118def5a8>
# left: <__main__.DT_Node instance at 0x118def5f0>
# right: <__main__.DT_Node instance at 0x118def638>
# subset: (12, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118def7e8>
# left: <__main__.DT_Node instance at 0x118def830>
# right: <__main__.DT_Node instance at 0x118def878>
# subset: (52, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118defc20>
# left: <__main__.DT_Node instance at 0x118defcb0>
# right: <__main__.DT_Node instance at 0x118defcf8>
# subset: (181, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118dc8a28>
# left: <__main__.DT_Node instance at 0x118dc8a70>
# right: <__main__.DT_Node instance at 0x118dc8ab8>
# subset: (28, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118dc8dd0>
# left: <__main__.DT_Node instance at 0x118dc8e60>
# right: <__main__.DT_Node instance at 0x118dc8ea8>
# subset: (72, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118def5f0>
# left: <__main__.DT_Node instance at 0x118def680>
# right: <__main__.DT_Node instance at 0x118def6c8>
# subset: (9, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118def830>
# left: <__main__.DT_Node instance at 0x118def8c0>
# right: <__main__.DT_Node instance at 0x118def908>
# subset: (51, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118defcf8>
# left: <__main__.DT_Node instance at 0x118defd40>
# right: <__main__.DT_Node instance at 0x118defd88>
# subset: (115, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118dc8a70>
# left: <__main__.DT_Node instance at 0x118dc8b00>
# right: <__main__.DT_Node instance at 0x118dc8b48>
# subset: (3, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118dc8ab8>
# left: <__main__.DT_Node instance at 0x118dc8c20>
# right: <__main__.DT_Node instance at 0x118dc8c68>
# subset: (25, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118dc8e60>
# left: <__main__.DT_Node instance at 0x118dc8ef0>
# right: <__main__.DT_Node instance at 0x118dc8f38>
# subset: (19, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118dc8ea8>
# left: <__main__.DT_Node instance at 0x118def170>
# right: <__main__.DT_Node instance at 0x118def1b8>
# subset: (53, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118def680>
# left: <__main__.DT_Node instance at 0x118def710>
# right: <__main__.DT_Node instance at 0x118def758>
# subset: (4, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118def908>
# left: <__main__.DT_Node instance at 0x118def950>
# right: <__main__.DT_Node instance at 0x118def998>
# subset: (27, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118defd40>
# left: <__main__.DT_Node instance at 0x118defdd0>
# right: <__main__.DT_Node instance at 0x118defe18>
# subset: (74, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118defd88>
# left: <__main__.DT_Node instance at 0x118dd4050>
# right: <__main__.DT_Node instance at 0x118dd4098>
# subset: (41, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118dc8c68>
# left: <__main__.DT_Node instance at 0x118dc8cb0>
# right: <__main__.DT_Node instance at 0x118dc8cf8>
# subset: (3, 23)
# label: None
#
# repr(currNode): <__main__.DT_Node instance at 0x118def1b8>
# left: <__main__.DT_Node instance at 0x118def200>
# right: <__main__.DT_Node instance at 0x118def248>
# subset: (21, 23)
# label: 0
#
# --------------------
# pruning node:  <__main__.DT_Node instance at 0x118def1b8>
# subset: 21
# label: 0
# validation_error:  0.122
# testing_error:  0.125
